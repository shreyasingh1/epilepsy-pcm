# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.manifold import TSNE 
from sklearn.preprocessing import StandardScaler 
from mpl_toolkits.mplot3d import Axes3D

# %%
df= pd.read_csv('data_PY16N008.csv') 
corr = df.corr(method = 'spearman')
plt.figure(figsize=(20,6))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='Blues')
plt.title('Spearman Correlation Heatmap')
plt.show()

# %%
y_true = df.iloc[:, 10].values
# x_data = df.drop(columns=['Unnamed: 0', 'significant','chNames', 'n2Zscore',  'p2Zscore','n1Latency','n2Latency','p2Latency','flipped','outcome'])
x_data = df.drop(columns=['Unnamed: 0','chNames','flipped','outcome'])

# %%
x_data
# Out:
#      significant  n1Zscore   n2Zscore  p2Zscore  n1Latency  n2Latency  \
# 0            0.0  3.448605  10.021596 -3.357011       24.0      188.0
# 1            0.0 -3.759664  -1.898576  6.637484       51.0      343.0
# 2            0.0 -1.355997  -2.757417 -0.926962       34.0      314.0
# 3            0.0  0.806587   1.924288  0.055253       32.0      315.0
# 4            0.0 -1.484699   1.810453  1.810453       22.0      101.0
# ..           ...       ...        ...       ...        ...        ...
# 547          0.0 -0.775927  -2.579947  4.290270       51.0      285.0
# 548          0.0  1.769931   5.228859 -3.093837       12.0      139.0
# 549          0.0  1.361718   2.097774 -1.999799       14.0      338.0
# 550          0.0 -2.863802  -2.631576  7.996893       44.0      228.0
# 551          0.0  4.730472   6.498267 -4.460485       16.0      143.0
#
#      p2Latency
# 0         67.0
# 1        182.0
# 2         76.0
# 3        125.0
# 4        101.0
# ..         ...
# 547      195.0
# 548       69.0
# 549      278.0
# 550      118.0
# 551       79.0
#
# [552 rows x 7 columns]

# %%
tsne = TSNE(verbose = 1, n_components=2, init='random', perplexity = 20, learning_rate=1000)
# X_std = StandardScaler().fit_transform(x_data) 
X_tsne = tsne.fit_transform(x_data) 
X_tsne_data = np.vstack((X_tsne.T, y_true)).T 
df_tsne = pd.DataFrame(X_tsne_data, columns=['Dim1', 'Dim2','class']) 
df_tsne.head()
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 552 samples in 0.001s...
# [t-SNE] Computed neighbors for 552 samples in 0.013s...
# [t-SNE] Computed conditional probabilities for sample 552 / 552
# [t-SNE] Mean sigma: 7.386579
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.871155
# [t-SNE] KL divergence after 1000 iterations: 0.537559
#         Dim1       Dim2  class
# 0   2.426412   7.380187    0.0
# 1 -50.956837  -3.940598    1.0
# 2 -36.811447  17.040382    0.0
# 3 -44.796196   6.329617    0.0
# 4  57.413849   4.802715    0.0

# %%
plt.figure(figsize=(8, 8)) 
sns.scatterplot(data=df_tsne, hue='class', x='Dim1', y='Dim2',s=4) 
plt.show()

# %%
tsne = TSNE(verbose = 1, n_components=3, init='random', perplexity = 20, learning_rate=1000)
# X_std = StandardScaler().fit_transform(x_data) 
X_tsne = tsne.fit_transform(x_data) 
X_tsne_data = np.vstack((X_tsne.T, y_true)).T 
df_tsne = pd.DataFrame(X_tsne_data, columns=['Dim1', 'Dim2','Dim3','class']) 
df_tsne.head()
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 552 samples in 0.000s...
# [t-SNE] Computed neighbors for 552 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 552 / 552
# [t-SNE] Mean sigma: 7.386579
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 103.715759
# [t-SNE] KL divergence after 1000 iterations: 2.020840
# [[ -90.777176  -40.961304   23.102232]
#  [ -20.562454   68.98332  -137.97424 ]
#  [ -19.31802   -38.129444  -95.540695]
#  ...
#  [  14.542588  153.97264   -87.71825 ]
#  [  30.716366  186.6522     34.73397 ]
#  [ -27.078316  -38.165462   84.954414]]
#          Dim1       Dim2        Dim3  class
# 0  -90.777176 -40.961304   23.102232    0.0
# 1  -20.562454  68.983322 -137.974243    1.0
# 2  -19.318020 -38.129444  -95.540695    0.0
# 3   20.769041  12.241396  -83.244125    0.0
# 4  139.652756 -56.101536   10.930587    0.0

# %%
fig = plt.figure(figsize=(8, 8))
ax = Axes3D(fig)
ax = plt.subplot(111, projection='3d')  
for row in df_tsne.itertuples(): 
    x = getattr(row,'Dim1')
    y = getattr(row,'Dim2')
    z = getattr(row,'Dim3')
    if getattr(row,'_4') == 0.0:
        ax.scatter(x,y,z, c='y', s=4) 
    elif getattr(row,'_4') == 1.0:
        ax.scatter(x,y,z, c='r',s=4) 
ax.set_zlabel('Z')  
ax.set_ylabel('Y')
ax.set_xlabel('X')
# ax.scatter(data=df_tsne, hue='class', x='Dim1', y='Dim2', z = 'Dim3')
plt.show()
