# %%
import numpy as np
import pandas as pd
import json
from epilepsypcm.utils.outcome_params import node_location

all_positive_patients = pd.read_csv("newDF.csv", sep = ',').reset_index(drop = True)

# %%
print(all_positive_patients["outcome"].value_counts())
all_positive_patients.head()
# Out:
# 0.0    268
# 1.0     41
# Name: outcome, dtype: int64
#    Unnamed: 0   Channels  outcome   SigResp   SigStim  N1RespAvg  N1RespSDV  \
# 0           0   LA9_LA10      0.0  0.000000  0.250000   1.530459   1.134169
# 1           1  LAH1_LAH2      1.0  0.076923  0.250000   7.062089  20.678040
# 2           2  LAH8_LAH9      0.0  0.307692  0.125000   4.032683   2.995624
# 3           3  LPH1_LPH2      0.0  0.115385  0.333333   6.522655  17.219698
# 4           4  LPH7_LPH8      0.0  0.307692  0.083333   7.304854  10.728727
#
#    N2RespAvg  N2RespSDV  P2RespAvg  P2RespSDV  N1StimAvg  N1StimSDV  \
# 0   2.040546   1.369091   1.304096   0.892887   7.178516  10.790559
# 1   3.320937   2.795194   2.178348   2.563587   7.883750  16.334814
# 2   3.450575   2.883998   2.376435   2.139730   2.505806   2.164878
# 3   3.369771   3.506524   2.281413   3.303814   6.505212   8.264811
# 4   4.610356   4.159990   3.468193   2.645476   2.823084   2.925869
#
#    N2StimAvg  N2StimSDV  P2StimAvg  P2StimSDV
# 0   6.536859   6.383906   5.785279   7.331337
# 1   4.921208   3.029861   2.352152   1.803711
# 2   2.190308   1.489418   2.033410   2.112725
# 3   4.630948   3.574869   4.187831   3.626223
# 4   1.606341   1.075715   1.461462   1.012732

# %%
from epilepsypcm.utils.make_df import make_df, get_df_list, concat_dfs
from epilepsypcm.models.base_models import *
from sklearn.metrics import auc

# %% [markdown]
# # Plotting everything for RF

# %%
all_positive_patients = pd.read_csv("newDF.csv", sep = ',').reset_index(drop = True)

X_list = ["Channels","SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV"]

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

# REGULAR FEATURES

#random forest regular
smote = False
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest Regular, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest SMOTE
smote = True
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest + Smote, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')


#random forest random upsample
smote = "resample"
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest + Random Upsample, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')


# REGULAR FEATURES + NETWORK FEATURES

all_positive_patients = pd.read_csv("networkfeaturesfixed.csv", sep = ',').reset_index(drop = True)

print(all_positive_patients["outcome"].value_counts())
all_positive_patients.head()

X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "EV", "Closeness"]

#random forest with network features
smote = False
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest + Network Features, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest with network features SMOTE
smote = True
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest + Network Features + Smote, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')


#random forest with network features random upsample
smote = "resample"
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest + Network Features + Random Upsample, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# Random Forest - Number of mislabeled points out of a total 78 points : 12
# Random Forest - Number of mislabeled points out of a total 78 points : 12
# 0.0    259
# 1.0     41
# Name: outcome, dtype: int64
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# Random Forest - Number of mislabeled points out of a total 75 points : 11
# Random Forest - Number of mislabeled points out of a total 75 points : 9

# %%
all_positive_patients = pd.read_csv("newDF.csv", sep = ',').reset_index(drop = True)

X_list = ["Channels","SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV"]

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

# REGULAR FEATURES

#random forest regular
smote = False
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest Regular, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest + smote
smote = True
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest + Smote, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest + random upsample
smote = "resample"
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest + Random Upsample, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')



# REGULAR FEATURES + NETWORK FEATURES

all_positive_patients = pd.read_csv("networkfeaturesfixed.csv", sep = ',').reset_index(drop = True)

print(all_positive_patients["outcome"].value_counts())
all_positive_patients.head()

X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "EV", "Closeness"]

#random forest + network features
smote = False
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest + Network Features, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest + network features + smote
smote = True
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest + Network Features + Smote, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest + network features + random upsample
smote = "resample"
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest + Network Features + Random Upsample, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# Random Forest - Number of mislabeled points out of a total 78 points : 11
# 0.0    259
# 1.0     41
# Name: outcome, dtype: int64
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# Random Forest - Number of mislabeled points out of a total 75 points : 11
# Random Forest - Number of mislabeled points out of a total 75 points : 11

# %% [markdown]
# ## Results with stim + response channels

# %%
all_positive_patients = pd.read_csv("newDF.csv", sep = ',').reset_index(drop = True)

X_list = ["Channels","SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV"]

# %%
# stim + resp channels

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Logistic Regression - Number of mislabeled points out of a total 78 points : 10
# Naive Bayes - Number of mislabeled points out of a total 78 points : 32
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# [22:07:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 10
# Adaboost - Number of mislabeled points out of a total 78 points : 6
# SVM - Number of mislabeled points out of a total 78 points : 10

# %%
plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Logistic Regression - Number of mislabeled points out of a total 78 points : 10
# Naive Bayes - Number of mislabeled points out of a total 78 points : 32
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# [22:07:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 10
# Adaboost - Number of mislabeled points out of a total 78 points : 6
# SVM - Number of mislabeled points out of a total 78 points : 10

# %% [markdown]
# # Random Forest Model

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)

# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# Optimal roc threshold:  0.13052631578947368
# Accuracy:  0.7051282051282052
# Sensitivity:  0.8
# Specificity:  0.6911764705882353

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] >= optimal_thresh: #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] >= optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left basal temporal
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - left amygdala
# Correctly labeled - Right hippocampal depth
# Correctly labeled - left amygdala
# Correctly labeled - Left inferior posterior frontal depth
# Mislabeled - Right amygdala depth
#
#
# Negative labels
# Mislabeled - Right anterior hippocampus
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right medial frontal depth
# Mislabeled - Right frontal grid
# Mislabeled - Right amygdala
# Mislabeled - Left fronto-parietal grid
# Mislabeled - Right medial tumor inferior
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - left posterior hippocampus
# Mislabeled - Right lateral tumor superior
# Mislabeled - Right medial tumor medial
# Mislabeled - Left frontal
# Mislabeled - right posterior hippocampus
# Mislabeled - Left amygdala
# Mislabeled - Left sensory area
# Mislabeled - Right orbitofrontal depth
# Mislabeled - Left fronto-temporal grid
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left anterior cingulate
# Correctly labeled - left anterior hippocampus
# Correctly labeled - which patient?
# Correctly labeled - left posterior hippocampus
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left posterior cingulate
# Correctly labeled - Basal temporal anterior
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left amygdala depth
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left amygdala depth
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - Left sensory area
# Correctly labeled - right posterior hippocampus
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Right fusiform
# Correctly labeled - Right amygdala
# Correctly labeled - Left frontal operculum
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Right anterior insular depth
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left frontal
# Correctly labeled - Left anterior basal temporal gyrus
# Correctly labeled - Right piriform
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left frontal operculum
# Correctly labeled - Basal temporal posterior-temporal

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  N1StimAvg
# Least Significant Feature:  SigResp

# %% [markdown]
# ## RF - SMOTE

# %%
all_positive_patients = pd.read_csv("newDF.csv", sep = ",").reset_index(drop = True)

X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV"]

# %%
# stim + resp channels

smote = True

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# Logistic Regression - Number of mislabeled points out of a total 78 points : 24
# Naive Bayes - Number of mislabeled points out of a total 78 points : 30
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# [22:07:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 12
# Adaboost - Number of mislabeled points out of a total 78 points : 19
# SVM - Number of mislabeled points out of a total 78 points : 24
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
smote = True

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression - Number of mislabeled points out of a total 78 points : 25
# Naive Bayes - Number of mislabeled points out of a total 78 points : 31
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# [22:07:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 12
# Adaboost - Number of mislabeled points out of a total 78 points : 17
# SVM - Number of mislabeled points out of a total 78 points : 23
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

smote = True

max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# Optimal roc threshold:  0.1921103896103896
# Accuracy:  0.717948717948718
# Sensitivity:  0.9
# Specificity:  0.6911764705882353

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] >= optimal_thresh: #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] >= optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left basal temporal
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - left amygdala
# Correctly labeled - Left inferior posterior frontal depth
# Correctly labeled - left amygdala
# Correctly labeled - Right hippocampal depth
# Correctly labeled - Right amygdala depth
#
#
# Negative labels
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right medial frontal depth
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right anterior hippocampus
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right frontal grid
# Mislabeled - Right amygdala
# Mislabeled - left posterior hippocampus
# Mislabeled - Right orbitofrontal depth
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right medial tumor inferior
# Mislabeled - left posterior hippocampus
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left frontal
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left sensory area
# Mislabeled - Left amygdala
# Mislabeled - Right lateral tumor superior
# Mislabeled - Left fronto-parietal grid
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Right medial tumor medial
# Correctly labeled - Left anterior cingulate
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - left posterior hippocampus
# Correctly labeled - which patient?
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left frontal
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Basal temporal anterior
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - left posterior cingulate
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - left anterior hippocampus
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left amygdala depth
# Correctly labeled - Right fusiform
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left sensory area
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - Left amygdala depth
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Basal temporal posterior-temporal
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Right piriform
# Correctly labeled - Right anterior insular depth
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - Right amygdala
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left anterior basal temporal gyrus

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  P2RespAvg
# Least Significant Feature:  SigResp

# %% [markdown]
# ## RF - Duplicated Upsampling

# %%
all_positive_patients = pd.read_csv("newDF.csv", sep = ",").reset_index(drop = True)

X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV"]

# %%
# stim + resp channels

smote = "resample"

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# Logistic Regression - Number of mislabeled points out of a total 78 points : 28
# Naive Bayes - Number of mislabeled points out of a total 78 points : 32
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# [22:07:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 8
# Adaboost - Number of mislabeled points out of a total 78 points : 17
# SVM - Number of mislabeled points out of a total 78 points : 25
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
smote = "resample"

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression - Number of mislabeled points out of a total 78 points : 25
# Naive Bayes - Number of mislabeled points out of a total 78 points : 33
# Random Forest - Number of mislabeled points out of a total 78 points : 10
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:07:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 78 points : 10
# Adaboost - Number of mislabeled points out of a total 78 points : 18
# SVM - Number of mislabeled points out of a total 78 points : 25

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

smote = "resample"

max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Random Forest - Number of mislabeled points out of a total 78 points : 9
# Optimal roc threshold:  0.18
# Accuracy:  0.782051282051282
# Sensitivity:  0.8
# Specificity:  0.7794117647058824

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] > (optimal_thresh + 0.01): #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < (optimal_thresh + 0.01):
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] > optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left basal temporal
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - left amygdala
# Correctly labeled - Left inferior posterior frontal depth
# Correctly labeled - left amygdala
# Mislabeled - Right hippocampal depth
# Mislabeled - Right amygdala depth
#
#
# Negative labels
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right medial frontal depth
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Right amygdala
# Mislabeled - Right anterior hippocampus
# Mislabeled - Left fronto-temporal grid
# Mislabeled - left posterior hippocampus
# Mislabeled - Left sensory area
# Mislabeled - Right medial tumor inferior
# Mislabeled - Right frontal grid
# Mislabeled - Left amygdala
# Mislabeled - Right lateral tumor superior
# Mislabeled - Left fronto-temporal grid
# Correctly labeled - Left anterior cingulate
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Right medial tumor medial
# Correctly labeled - Right orbitofrontal depth
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left frontal
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Basal temporal anterior
# Correctly labeled - which patient?
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left amygdala depth
# Correctly labeled - left anterior hippocampus
# Correctly labeled - left posterior hippocampus
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left frontal
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left sensory area
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Right fusiform
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Right piriform
# Correctly labeled - Right anterior insular depth
# Correctly labeled - Right amygdala
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left posterior nodule depth
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left anterior basal temporal gyrus
# Correctly labeled - Left amygdala depth
# Correctly labeled - Basal temporal posterior-temporal

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  P2RespAvg
# Least Significant Feature:  SigStim

# %% [markdown]
# # RF network feature + upsampling comparison

# %%
all_positive_patients = pd.read_csv("networkfeatures1.csv", sep = ',').reset_index(drop = True)

X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "InDegree",
          "OutDegree", "EV", "Closeness"]

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

# roc
smote = False
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "RF: Node-Based + Network Features, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

smote = True
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "RF: Node-Based + Network Features + SMOTE, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

smote = "resample"
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "RF: Node-Based + Network Features + Random Upsampling, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

# pr
plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

smote = False
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='RF: Node-Based + Network Features, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

smote = True
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='RF: Node-Based + Network Features + SMOTE, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

smote = "resample"
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='RF: Node-Based + Network Features + Random Upsampling, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# Random Forest - Number of mislabeled points out of a total 75 points : 12
# Random Forest - Number of mislabeled points out of a total 75 points : 10
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# Random Forest - Number of mislabeled points out of a total 75 points : 13
# Random Forest - Number of mislabeled points out of a total 75 points : 10

# %%
from sklearn.metrics import confusion_matrix


#reg
print("Reg")
smote = False
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("TN: ", tn, "FP: ", fp, "TP: ", tp, "FN: ", fn)
print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp), "\n")

#smote
print("Smote")
smote = True
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]

print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("TN: ", tn, "FP: ", fp, "TP: ", tp, "FN: ", fn)
print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp), "\n")

#random upsample
print("Upsample")
smote = "resample"
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("TN: ", tn, "FP: ", fp, "TP: ", tp, "FN: ", fn)
print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Reg
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# Optimal roc threshold:  0.17
# TN:  46 FP:  19 TP:  9 FN:  1
# Accuracy:  0.7333333333333333
# Sensitivity:  0.9
# Specificity:  0.7076923076923077
#
# Smote
# Random Forest - Number of mislabeled points out of a total 75 points : 12
# Optimal roc threshold:  0.4176839883280561
# TN:  55 FP:  10 TP:  8 FN:  2
# Accuracy:  0.84
# Sensitivity:  0.8
# Specificity:  0.8461538461538461
#
# Upsample
# Random Forest - Number of mislabeled points out of a total 75 points : 11
# Optimal roc threshold:  0.26625
# TN:  49 FP:  16 TP:  9 FN:  1
# Accuracy:  0.7733333333333333
# Sensitivity:  0.9
# Specificity:  0.7538461538461538

# %% [markdown]
# ## RF - new network features, no upsampling

# %%
all_positive_patients = pd.read_csv("networkfeatures1.csv", sep = ',').reset_index(drop = True)

print(all_positive_patients["outcome"].value_counts())
all_positive_patients.head()
# Out:
# 0.0    259
# 1.0     41
# Name: outcome, dtype: int64
#    Unnamed: 0   Channels  outcome   SigResp   SigStim  N1RespAvg  N1RespSDV  \
# 0           0   LA9_LA10      0.0  0.000000  0.250000   1.530459   1.134169
# 1           1  LAH1_LAH2      1.0  0.076923  0.250000   7.062089  20.678040
# 2           2  LAH8_LAH9      0.0  0.307692  0.125000   4.032683   2.995624
# 3           3  LPH1_LPH2      0.0  0.115385  0.333333   6.522655  17.219698
# 4           4  LPH7_LPH8      0.0  0.307692  0.083333   7.304854  10.728727
#
#    N2RespAvg  N2RespSDV  P2RespAvg  ...  N1StimAvg  N1StimSDV  N2StimAvg  \
# 0   2.040546   1.369091   1.304096  ...   7.178516  10.790559   6.536859
# 1   3.320937   2.795194   2.178348  ...   7.883750  16.334814   4.921208
# 2   3.450575   2.883998   2.376435  ...   2.505806   2.164878   2.190308
# 3   3.369771   3.506524   2.281413  ...   6.505212   8.264811   4.630948
# 4   4.610356   4.159990   3.468193  ...   2.823084   2.925869   1.606341
#
#    N2StimSDV  P2StimAvg  P2StimSDV  InDegree  OutDegree            EV  \
# 0   6.383906   5.785279   7.331337  0.000000   0.222222  5.165334e-14
# 1   3.029861   2.352152   1.803711  0.074074   0.222222  7.960607e-04
# 2   1.489418   2.033410   2.112725  0.296296   0.111111  1.590588e-01
# 3   3.574869   4.187831   3.626223  0.111111   0.296296  4.743270e-03
# 4   1.075715   1.461462   1.012732  0.296296   0.074074  1.857524e-01
#
#    Closeness
# 0   0.000000
# 1   0.177778
# 2   0.484848
# 3   0.222222
# 4   0.484848
#
# [5 rows x 21 columns]

# %%
X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "InDegree",
          "OutDegree", "EV", "Closeness"]

# %%
# stim + resp channels

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")
'''
#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
'''
#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

'''#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
'''
# Out:
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# '#xgboost\nlearning_rate = 0.5\nmax_depth = 10\nn_estimators = 10\nxgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)\nplt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))\nplt.legend(loc=\'lower right\')\n\n#adaboost\nn_estimators = 10\nada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)\nplt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))\nplt.legend(loc=\'lower right\')\n\n#svm\nC = 0.7\nepsilon = 0.2\nsv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)\nplt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))\nplt.legend(loc=\'lower right\')\n'

# %%
plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

'''#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
'''
#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

'''#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')'''
# Out:
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# "#xgboost\nlearning_rate = 0.5\nmax_depth = 10\nn_estimators = 10\nxgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr)\nplt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))\nplt.legend(loc='lower right')\n\n#adaboost\nn_estimators = 10\nada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr)\nplt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))\nplt.legend(loc='lower right')\n\n#svm\nC = 0.7\nepsilon = 0.2\nsv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)\nplt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))\nplt.legend(loc='lower right')"

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

#max_depth = 10
#rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr)
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr)


# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# SVM - Number of mislabeled points out of a total 75 points : 10
# Optimal roc threshold:  0.19942147864332369
# Accuracy:  0.72
# Sensitivity:  0.8
# Specificity:  0.7076923076923077

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] >= optimal_thresh: #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] >= optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - left anterior hippocampus
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Right amygdala depth
# Correctly labeled - left basal temporal
# Correctly labeled - Left orbitofrontal depth
# Correctly labeled - Left inferior frontal
# Correctly labeled - left amygdala
# Correctly labeled - Left inferior posterior frontal depth
# Correctly labeled - right posterior hippocampus
# Mislabeled - Right anterior temporal inferior
#
#
# Negative labels
# Mislabeled - Right piriform
# Mislabeled - Left amygdala depth
# Mislabeled - Right anterior hippocampus
# Mislabeled - Left posterior cortical dysplasia
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left nodule E
# Mislabeled - Right amygdala
# Mislabeled - Left frontal
# Mislabeled - Left fronto-parietal grid
# Mislabeled - Right frontal grid
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left amygdala
# Mislabeled - left posterior hippocampus
# Mislabeled - left posterior hippocampus
# Mislabeled - left amygdala
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left superior frontal depth
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right orbitofrontal depth
# Correctly labeled - Basal temporal anterior
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right medial tumor inferior
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left anterior cingulate
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left sensory area
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Right lateral tumor superior
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left frontal
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left posterior operculum
# Correctly labeled - which patient?
# Correctly labeled - Left anterior nodule depth
# Correctly labeled - left posterior hippocampus
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Right Para hippocampal gyrus
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - Right fusiform
# Correctly labeled - Right medial tumor medial
# Correctly labeled - left posterior cingulate
# Correctly labeled - Left amygdala
# Correctly labeled - Left amygdala
# Correctly labeled - Left supplemental motor area
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - Right amygdala
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left frontal operculum
# Correctly labeled - Right amygdala depth
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left anterior hippocampus

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  N1RespSDV
# Least Significant Feature:  OutDegree

# %% [markdown]
# ## Network features + SMOTE

# %%
all_positive_patients = pd.read_csv("networkfeatures1.csv", sep = ',').reset_index(drop = True)

# %%
X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "InDegree",
          "OutDegree", "EV", "Closeness"]

# %%
# stim + resp channels

smote = True

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# Logistic Regression - Number of mislabeled points out of a total 75 points : 23
# Naive Bayes - Number of mislabeled points out of a total 75 points : 26
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Random Forest - Number of mislabeled points out of a total 75 points : 12
# [22:07:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 75 points : 13
# Adaboost - Number of mislabeled points out of a total 75 points : 19
# SVM - Number of mislabeled points out of a total 75 points : 22
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
smote = True

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression - Number of mislabeled points out of a total 75 points : 25
# Naive Bayes - Number of mislabeled points out of a total 75 points : 27
# Random Forest - Number of mislabeled points out of a total 75 points : 10
# [22:07:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 75 points : 13
# Adaboost - Number of mislabeled points out of a total 75 points : 24
# SVM - Number of mislabeled points out of a total 75 points : 25
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

smote = True

max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Random Forest - Number of mislabeled points out of a total 75 points : 12
# Optimal roc threshold:  0.429140704967659
# Accuracy:  0.8533333333333334
# Sensitivity:  0.8
# Specificity:  0.8615384615384616

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] >= optimal_thresh: #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] >= optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - Left inferior posterior frontal depth
# Correctly labeled - left posterior hippocampus
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left inferior frontal
# Correctly labeled - left amygdala
# Correctly labeled - Right anterior temporal inferior
# Correctly labeled - Left orbitofrontal depth
# Correctly labeled - Right amygdala depth
# Correctly labeled - right posterior hippocampus
# Mislabeled - left basal temporal
#
#
# Negative labels
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left nodule E
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left amygdala depth
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - left posterior hippocampus
# Mislabeled - left amygdala
# Mislabeled - Right frontal grid
# Correctly labeled - Left sensory area
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Right medial tumor inferior
# Correctly labeled - Left amygdala
# Correctly labeled - Right medial tumor medial
# Correctly labeled - Left superior frontal depth
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right orbitofrontal depth
# Correctly labeled - Basal temporal anterior
# Correctly labeled - left posterior hippocampus
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Right lateral tumor superior
# Correctly labeled - Left frontal
# Correctly labeled - which patient?
# Correctly labeled - Left frontal
# Correctly labeled - Left anterior cingulate
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left anterior nodule depth
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left supplemental motor area
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - Right amygdala
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Right fusiform
# Correctly labeled - Right Para hippocampal gyrus
# Correctly labeled - Left amygdala
# Correctly labeled - left posterior cingulate
# Correctly labeled - left posterior cingulate
# Correctly labeled - Right piriform
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Right amygdala depth
# Correctly labeled - Right amygdala
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left anterior hippocampus
# Correctly labeled - Left amygdala

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  P2RespAvg
# Least Significant Feature:  OutDegree

# %% [markdown]
# # RF + Network Features + Random Upsampling

# %%
all_positive_patients = pd.read_csv("networkfeatures1.csv", sep = ',').reset_index(drop = True)

# %%
X_list = ["Channels", "SigResp", "N1RespAvg", "N1RespSDV", "N2RespAvg", "N2RespSDV", "P2RespAvg", "P2RespSDV", 
          "SigStim", "N1StimAvg", "N1StimSDV", "N2StimAvg", "N2StimSDV", "P2StimAvg", "P2StimSDV", "InDegree",
          "OutDegree", "EV", "Closeness"]

# %%
# stim + resp channels

smote = "resample"

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("ROC Curves")
plt.xlabel("fpr")
plt.ylabel("tpr")

#logistic regression
lr, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Logistic Regression, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#naive bayes
gnb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Naive Bayes, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Random Forest, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "XGBoost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "Adaboost, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(fpr, tpr, label = "SVM, AUC = %0.2f" % auc(fpr, tpr))
plt.legend(loc='lower right')
# Out:
# Logistic Regression - Number of mislabeled points out of a total 75 points : 25
# Naive Bayes - Number of mislabeled points out of a total 75 points : 29
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# [22:07:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGBoost - Number of mislabeled points out of a total 75 points : 15
# Adaboost - Number of mislabeled points out of a total 75 points : 18
# SVM - Number of mislabeled points out of a total 75 points : 20

# %%
smote = "resample"

plot_roc = False
plot_pr = False

plt.figure(figsize = (10,10))
plt.title("PR Curves")
plt.xlabel("recall")
plt.ylabel("precision")

#logistic regression
lr, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = logistic_regression(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Logistic Regression, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#naive bayes
gnb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = naive_bayes(all_positive_patients, X_list, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Naive Bayes, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#random forest
max_depth = 10
rf, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Random Forest, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#xgboost
learning_rate = 0.5
max_depth = 10
n_estimators = 10
xgb, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = xgboost(all_positive_patients, X_list, learning_rate, max_depth, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='XGBoost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#adaboost
n_estimators = 10
ada, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = adaboost(all_positive_patients, X_list, n_estimators, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='Adaboost, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')

#svm
C = 0.7
epsilon = 0.2
sv, y_pred, test_channels, y_test, tpr, fpr, roc_thresholds, precision, recall = svm(all_positive_patients, X_list, C, epsilon, plot_roc, plot_pr, smote)
plt.plot(recall, precision, label='SVM, AP = %0.2f' % (np.mean(precision)))
plt.legend(loc='lower right')
# Out:
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression - Number of mislabeled points out of a total 75 points : 26
# Naive Bayes - Number of mislabeled points out of a total 75 points : 33
# Random Forest - Number of mislabeled points out of a total 75 points : 9
# [22:07:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:07:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost - Number of mislabeled points out of a total 75 points : 10
# Adaboost - Number of mislabeled points out of a total 75 points : 23
# SVM - Number of mislabeled points out of a total 75 points : 28
# /Users/shrey2/opt/anaconda3/envs/pcm/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
#getting model and stats
from sklearn.metrics import confusion_matrix

smote = "resample"

max_depth = 10
rf, test_channels, y_pred, y_test, tpr, fpr, roc_thresholds, precision, recall = random_forest(all_positive_patients, X_list, max_depth, plot_roc, plot_pr, smote)

# Printing Metrics
optimal_thresh = roc_thresholds[np.argmax(tpr - fpr)]
print("Optimal roc threshold: ", optimal_thresh)
y_rounded = np.where(y_pred > optimal_thresh, 1, 0)

tn, fp, fn, tp = confusion_matrix(y_test, y_rounded).ravel()

print("Accuracy: ", (tp + tn)/(tp + fp + tn + fn))
print("Sensitivity: ", tp / (tp + fn))
print("Specificity: ", tn / (tn + fp))
# Out:
# Random Forest - Number of mislabeled points out of a total 75 points : 12
# Optimal roc threshold:  0.2916985300249748
# Accuracy:  0.8133333333333334
# Sensitivity:  0.9
# Specificity:  0.8

# %%
# getting labels

epilepsy_normal = []
channels_normal = []
correct_normal = []

non_epilepsy = []
channels_non = []
correct_non = []

i = 0
while i < len(y_test):
    if list(y_test)[i] == 1.0:
        epilepsy_normal.append(y_pred[i])
        channels_normal.append(test_channels[i])
        
        if y_pred[i] >= optimal_thresh: #seeing if prediction was correct for true positives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Correctly labeled - " + label)
            
        elif y_pred[i] < optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_normal.append("Mislabeled - " + label)
            
    elif list(y_test)[i] == 0.0:
        non_epilepsy.append(y_pred[i])
        channels_non.append(test_channels[i])
        
        if y_pred[i] < optimal_thresh: #seeing if prediction was correct for true negatives
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Correctly labeled - " + label)            
            
        elif y_pred[i] >= optimal_thresh:
            
            no_digits = ''.join(i for i in test_channels[i] if not i.isdigit()) #dropping digits from channel name
            channel_split = no_digits.split("_")
            for key in node_location.keys():
                if (channel_split[0] == key) | (channel_split[1] == key): # if channel matches node label, label it
                    label = node_location[key]
            correct_non.append("Mislabeled - " + label)    
    
    i += 1
    
correct_normal_ordered = [x for _,x in sorted(zip(epilepsy_normal, correct_normal), reverse = True)]
correct_non_ordered = [x for _,x in sorted(zip(non_epilepsy, correct_non), reverse = True)]
            
print("\n")
print("Positive labels")            
print(*correct_normal_ordered, sep = "\n")

print("\n")
print("Negative labels")
print(*correct_non_ordered, sep = "\n")
# Out:
# Positive labels
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left inferior posterior frontal depth
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left orbitofrontal depth
# Correctly labeled - Left inferior frontal
# Correctly labeled - Right amygdala depth
# Correctly labeled - left amygdala
# Correctly labeled - Right anterior temporal inferior
# Correctly labeled - right posterior hippocampus
# Correctly labeled - left basal temporal
#
#
# Negative labels
# Mislabeled - Basal temporal posterior-temporal
# Mislabeled - Left amygdala depth
# Mislabeled - Left nodule E
# Mislabeled - left amygdala
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - Left fronto-temporal grid
# Mislabeled - left posterior hippocampus
# Mislabeled - left posterior hippocampus
# Mislabeled - right posterior hippocampus
# Mislabeled - Right lateral tumor superior
# Mislabeled - Right medial tumor inferior
# Correctly labeled - Right anterior hippocampus
# Correctly labeled - Right medial tumor medial
# Correctly labeled - Left amygdala
# Correctly labeled - Basal temporal anterior
# Correctly labeled - Left superior frontal depth
# Correctly labeled - Right frontal grid
# Correctly labeled - Left sensory area
# Correctly labeled - Left anterior cingulate
# Correctly labeled - Right orbitofrontal depth
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left frontal
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - right posterior hippocampus
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right amygdala
# Correctly labeled - Left supplemental motor area
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - which patient?
# Correctly labeled - left posterior hippocampus
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left anterior nodule depth
# Correctly labeled - left posterior cingulate
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left frontal
# Correctly labeled - left posterior cingulate
# Correctly labeled - Right piriform
# Correctly labeled - Right Para hippocampal gyrus
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Right posterior temporal inferior
# Correctly labeled - Right fusiform
# Correctly labeled - Left posterior superior temporal
# Correctly labeled - Left lateral lesion 4
# Correctly labeled - left anterior hippocampus
# Correctly labeled - Right amygdala depth
# Correctly labeled - Right amygdala
# Correctly labeled - Left retro-splenial cingulate
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior operculum
# Correctly labeled - Left posterior cortical dysplasia
# Correctly labeled - Left middle nodule depth
# Correctly labeled - Left lateral lesion 3
# Correctly labeled - Left lateral lesion 1
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-temporal grid
# Correctly labeled - Left fronto-parietal grid
# Correctly labeled - Left frontal operculum
# Correctly labeled - Left anterior hippocampus
# Correctly labeled - Left amygdala
# Correctly labeled - Left amygdala

# %%
# Plotting boxplot
import seaborn as sns

plt.figure(figsize = (10, 10))
plt.title("Random Forest boxplots")
plt.xlabel("non_SOZ                                                                               SOZ")
plt.ylabel("P(SOZ)")
plt.ylim([0,1])

sns.boxplot(
    data=[non_epilepsy, epilepsy_normal],
    palette=[sns.xkcd_rgb["light blue"], sns.xkcd_rgb["light orange"]],
    showmeans=True,
)

sns.stripplot(
    color = 'black',
    alpha = 0.3, 
    data=[non_epilepsy, epilepsy_normal],
)
# Out:
# <AxesSubplot:title={'center':'Random Forest boxplots'}, xlabel='non_SOZ                                                                               SOZ', ylabel='P(SOZ)'>

# %%
rf.feature_importances_

plt.barh(X_list[1:], rf.feature_importances_)
plt.xlim([0,.5])
print("Most Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(max(rf.feature_importances_))])
print("Least Significant Feature: ", X_list[1:][list(rf.feature_importances_).index(min(rf.feature_importances_))])
# Out:
# Most Significant Feature:  P2RespAvg
# Least Significant Feature:  N1StimSDV

# %% [markdown]
# # Training and testing by patients with crossvalidation

# %%
all_positive_patients = pd.read_csv("newDF_patientlabels.csv", sep = ',').reset_index(drop = True)
all_positive_patients["Channels"] = 0 #filling channels with null since smote doesn't preserve channel names

print(all_positive_patients["outcome"].value_counts())
all_positive_patients.head()
# Out:
# 0.0    259
# 1.0     41
# Name: outcome, dtype: int64
#    Unnamed: 0  Channels  outcome   SigResp   SigStim  N1RespAvg  N1RespSDV  \
# 0           0         0      0.0  0.000000  0.250000   1.530459   1.134169
# 1           1         0      1.0  0.076923  0.250000   7.062089  20.678040
# 2           2         0      0.0  0.307692  0.125000   4.032683   2.995624
# 3           3         0      0.0  0.115385  0.333333   6.522655  17.219698
# 4           4         0      0.0  0.307692  0.083333   7.304854  10.728727
#
#    N2RespAvg  N2RespSDV  P2RespAvg  ...  N1StimSDV  N2StimAvg  N2StimSDV  \
# 0   2.040546   1.369091   1.304096  ...  10.790559   6.536859   6.383906
# 1   3.320937   2.795194   2.178348  ...  16.334814   4.921208   3.029861
# 2   3.450575   2.883998   2.376435  ...   2.164878   2.190308   1.489418
# 3   3.369771   3.506524   2.281413  ...   8.264811   4.630948   3.574869
# 4   4.610356   4.159990   3.468193  ...   2.925869   1.606341   1.075715
#
#    P2StimAvg  P2StimSDV  patient  InDegree  OutDegree            EV  Closeness
# 0   5.785279   7.331337       30  0.000000   0.222222  5.165334e-14   0.000000
# 1   2.352152   1.803711       30  0.074074   0.222222  7.960607e-04   0.177778
# 2   2.033410   2.112725       30  0.296296   0.111111  1.590588e-01   0.484848
# 3   4.187831   3.626223       30  0.111111   0.296296  4.743270e-03   0.222222
# 4   1.461462   1.012732       30  0.296296   0.074074  1.857524e-01   0.484848
#
# [5 rows x 22 columns]

# %%
grouped = all_positive_patients.groupby(all_positive_patients.patient)

patient_list = set(list(all_positive_patients["patient"]))

dfs = []
for patient in patient_list:
    df = grouped.get_group(patient)
    dfs.append([patient, df])

# %%
from sklearn.model_selection import KFold
