# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
## Make the training and testing csv file, normalized
# read in the original file
df = pd.read_csv('/Users/david/Desktop/newDF.csv')
df = df.iloc[:,2:]

# apply the standard scaler
scaler = StandardScaler()
df.iloc[:,1:] = scaler.fit_transform(df.iloc[:,1:])

# train test split
df_train, df_test = train_test_split(df,test_size=0.25, random_state=100)

# export the training and testing csv file
df_train.to_csv('PCM_train.csv',index = False)
df_test.to_csv('PCM_test.csv',index = False)

# %%
## Make the Dataset
class PCMDataset(torch.utils.data.Dataset):

  def __init__(self, src_file):
    all_data = pd.read_csv(src_file, skiprows=0).to_numpy()  # strip IDs off

    self.x_data = torch.tensor(all_data[:,1:],dtype=torch.float32).to(device)
    self.y_data = torch.tensor(all_data[:,0],dtype=torch.float32).to(device)
    self.y_data = self.y_data.reshape(-1,1)

  def __len__(self):
    return len(self.x_data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    preds = self.x_data[idx,:]  # idx rows, all 4 cols
    lbl = self.y_data[idx,:]    # idx rows, the 1 col
    sample = { 'predictors' : preds, 'target' : lbl }
    return sample

# %%
# Verification that the PCMDataset is working
src = '/Users/david/Desktop/PCM_test.csv'
train_ds = PCMDataset(src)
train_ldr = torch.utils.data.DataLoader(train_ds, batch_size=2, shuffle=True)
for epoch in range(2):
  print("\n\n Epoch = " + str(epoch))
  for (bat_idx, batch) in enumerate(train_ldr):
    print("------------------------------")
    X = batch['predictors']
    Y = batch['target']
    print("bat_idx = " + str(bat_idx))
    print(X)
    print(Y)

print("End test ")
# Out:
#  Epoch = 0
# ------------------------------
# bat_idx = 0
# tensor([[-1.2929, -1.1954, -1.0058, -0.8590, -1.0906, -0.9732, -1.1785, -0.8222,
#          -0.8753, -0.7798, -0.9283, -0.8210, -1.0470, -0.7732],
#         [-0.0266, -0.0272,  0.3612,  0.7005,  0.4742,  0.2032,  0.2786,  0.1418,
#          -0.3854, -0.3436, -0.4564, -0.5992, -0.2934, -0.3461]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 1
# tensor([[-0.8643,  0.0896, -0.1861,  0.4611, -0.6988, -0.6980, -0.8082, -0.5862,
#          -0.0733,  0.2162, -0.3389, -0.5668, -0.6478, -0.6178],
#         [ 0.4798, -0.0272,  0.3931,  0.4468,  0.1833, -0.3037,  0.2067,  0.0324,
#          -0.3592, -0.4319, -0.4427, -0.4015, -0.3588, -0.3747]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 2
# tensor([[ 1.8023,  0.8035,  1.6817,  1.0111,  1.0034,  0.1335,  1.5408,  0.1130,
#           0.6986,  0.3620, -0.1068, -0.3771,  0.4216,  0.0098],
#         [-0.8852, -1.1954, -0.7871, -0.6727, -0.9461, -0.8720, -0.9292, -0.6732,
#          -0.7986, -0.7617, -0.8101, -0.7829, -0.8094, -0.7275]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 3
# tensor([[-0.8852,  0.9133, -0.7464, -0.6571, -0.6514, -0.8097, -0.6532, -0.5272,
#          -0.0945, -0.2795,  0.7387,  0.4902,  0.6513,  0.3736],
#         [-0.7864, -0.7282, -0.5795, -0.5816, -0.4487, -0.1423, -0.6829, -0.4085,
#          -0.6434, -0.4151, -0.3028,  0.5056, -0.1854,  0.5048]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 4
# tensor([[ 0.4798, -0.2609,  1.2299,  2.0711,  1.3942,  2.0318,  2.4702,  2.8692,
#          -0.4624, -0.5048, -0.4761, -0.5927, -0.7188, -0.6701],
#         [-1.2929, -0.9447, -0.8871, -0.8436, -0.9196, -0.8857, -1.0134, -0.8277,
#          -0.7103, -0.4272, -0.7944, -0.7526, -0.8189, -0.6153]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 5
# tensor([[ 0.2071, -0.3388, -0.5344, -0.6257, -0.3667, -0.5465, -0.4988, -0.2853,
#          -0.5953, -0.5711, -0.6644, -0.7111, -0.5230, -0.6154],
#         [-0.8852,  0.7815, -0.6790, -0.6405, -0.4656, -0.4067, -0.4534, -0.2030,
#          -0.0307, -0.1394,  0.9512,  0.9330,  0.2251, -0.0338]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 6
# tensor([[ 0.0660, -0.2729, -0.3380, -0.3721, -0.2711, -0.3924, -0.1415, -0.0577,
#          -0.6147, -0.6491, -0.3772, -0.4407, -0.0657,  0.1042],
#         [-0.1786, -1.1954, -0.5677, -0.6007,  0.3166,  0.6409, -0.9676, -0.7870,
#          -0.8176, -0.7609, -0.8697, -0.8402, -0.8886, -0.7622]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 7
# tensor([[-1.2929, -1.1954, -0.8770, -0.8343, -0.6476, -0.6524, -0.8210, -0.7621,
#          -0.8008, -0.7601, -0.5056, -0.6260, -0.9854, -0.7108],
#         [-1.2929, -1.1954, -0.7804, -0.8402, -0.6429, -0.7256, -0.5100, -0.7376,
#          -0.7973, -0.7825, -0.7008, -0.7904, -0.8537, -0.6529]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 8
# tensor([[-0.7357, -0.9249, -0.6782, -0.4665, -0.5635, -0.3115, -0.8646, -0.5660,
#          -0.8531, -0.7362, -0.8524, -0.6610, -0.8691, -0.6681],
#         [-0.7493, -0.1411, -0.6569, -0.5158, -0.6767, -0.5921, -1.0360, -0.7306,
#          -0.3253, -0.2923, -0.5004, -0.5705, -0.3669, -0.2867]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 9
# tensor([[ 1.4928,  1.2393,  3.0986,  3.1787,  3.6842,  3.6688,  3.8953,  2.0780,
#          -0.2441, -0.4188,  1.1128,  2.0565,  0.5196,  0.9542],
#         [-1.2929, -1.1954, -0.8675, -0.8409, -0.9023, -0.8332, -1.2218, -0.8875,
#          -0.8771, -0.7876, -0.7914, -0.7954, -0.9614, -0.7678]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 10
# tensor([[ 0.2990,  1.0075, -0.0731, -0.3345, -0.9726, -0.8630, -0.9110, -0.7449,
#           0.0445, -0.2696, -0.3897, -0.1362, -0.2042,  0.0083],
#         [-0.2214,  1.8029,  0.1309,  0.5541,  0.0338,  0.2984,  0.1606,  0.3436,
#           0.7455,  0.6468,  0.2211,  0.3180,  0.8275,  0.3193]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 11
# tensor([[-0.8643, -0.4047, -0.6814, -0.8033, -0.3733, -0.6041, -0.7150, -0.6508,
#          -0.6330, -0.6157, -0.7882, -0.6558, -0.7229, -0.5778],
#         [ 0.9357,  0.1572,  0.5389,  0.4613,  0.0572,  0.1882,  1.8196,  2.3665,
#           0.1473,  0.2180, -0.1883,  0.3658,  1.2870,  2.0409]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 12
# tensor([[ 1.8023, -0.3388,  0.3740, -0.0952, -0.0407, -0.3136,  0.9260,  0.3264,
#          -0.3406, -0.1650, -0.6769, -0.6527, -0.4202, -0.5247],
#         [-0.0548, -0.9099,  0.1392,  0.1645,  0.5119,  0.6341,  0.6929,  0.2395,
#          -0.7243, -0.7077, -0.6610, -0.7337, -0.7119, -0.5614]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 13
# tensor([[-0.3417, -0.5365, -0.5488, -0.5932, -0.4525, -0.5367, -0.3475, -0.2912,
#          -0.5751, -0.5040, -0.5382, -0.5870, -0.5319, -0.5611],
#         [-1.2929, -1.1954, -0.8833, -0.8044, -0.7867, -0.8148, -1.0770, -0.7700,
#          -0.8258, -0.7654, -0.9285, -0.8162, -0.9793, -0.7957]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 14
# tensor([[ 0.1000, -1.1954,  0.4603, -0.1284, -0.2524, -0.6453,  0.2940, -0.2774,
#          -0.5081, -0.4088, -0.7996, -0.7509, -0.8587, -0.6410],
#         [-0.0266, -0.9618, -0.3247, -0.3172,  0.8742,  1.5827, -0.2514, -0.3559,
#          -0.7890, -0.7129, -0.5652, -0.4260, -1.0537, -0.7688]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 15
# tensor([[-1.0786, -0.5529, -0.7462, -0.5316, -0.7131, -0.4571, -0.8301, -0.5142,
#          -0.5519, -0.5742, -0.5052, -0.5436, -0.6540, -0.6560],
#         [ 0.1000,  2.6596,  2.2306,  1.6113,  0.7616,  0.8243,  2.3605,  0.7721,
#           2.8374,  1.8003,  0.3553,  0.2982,  2.2448,  0.8041]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 16
# tensor([[ 0.4737,  1.1769,  0.8836,  0.8842,  0.8299,  1.3087,  1.0070,  1.2870,
#           0.0872, -0.0886,  0.2764,  0.4441,  0.8312,  0.6254],
#         [ 0.8738,  1.0890,  2.4391,  2.3642,  3.7356,  3.5329,  3.0257,  1.3945,
#           0.6252,  0.6184,  0.3754,  0.4678,  0.6384,  0.5851]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 17
# tensor([[-0.0072, -0.3388,  0.5628,  1.8037,  0.6772,  0.7048,  1.1893,  0.7828,
#           0.0925,  0.8427, -0.3094,  0.2658,  0.0530,  0.1797],
#         [-1.2929, -1.1954, -0.8151, -0.8276, -0.3972, -0.4387, -1.1284, -0.8043,
#          -0.8490, -0.7764, -0.9526, -0.7400, -0.9971, -0.7576]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 18
# tensor([[ 0.2266, -0.7282, -0.0993, -0.0215,  0.5663,  0.9972, -0.3605, -0.1447,
#          -0.7348, -0.6718, -0.5428, -0.4971, -0.6994, -0.5349],
#         [-0.2482, -0.2317, -0.6988, -0.7444, -0.5643, -0.6488, -0.8372, -0.7479,
#          -0.4829, -0.5579, -0.7219, -0.7797, -0.5980, -0.5091]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 19
# tensor([[-0.7493, -0.5365, -0.7442, -0.6360, -0.4533, -0.2577, -0.6731, -0.5492,
#          -0.6036, -0.5717, -0.7298, -0.7058, -0.7047, -0.5442],
#         [-1.2929, -1.1954, -0.8158, -0.8110, -1.0413, -0.9259, -0.9175, -0.7767,
#          -0.6590, -0.6901, -0.7704, -0.7257, -0.7440, -0.6699]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 20
# tensor([[ 0.4095,  1.3746,  0.5515,  0.3193, -0.3277, -0.5140,  0.2017, -0.2235,
#           0.8701,  0.3451,  0.1212, -0.3545,  0.5775, -0.1905],
#         [-0.0548, -0.0532, -0.4213, -0.6120, -0.1760, -0.2939, -0.0867, -0.2050,
#          -0.4306, -0.4392, -0.2021, -0.1434, -0.4942, -0.4095]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 21
# tensor([[ 9.9981e-02,  6.6070e-01, -1.1139e-01, -3.8847e-02, -2.8407e-01,
#          -2.3652e-01,  2.9636e-01, -1.5173e-01,  1.6314e-01, -5.9253e-04,
#          -1.4074e-01, -3.8159e-01,  1.1885e+00,  9.1617e-01],
#         [-8.2858e-01, -7.6710e-01, -8.1457e-01, -6.6396e-01, -6.3536e-01,
#          -2.3875e-01, -4.1261e-01,  1.6613e-01, -8.2690e-01, -7.2377e-01,
#          -7.1025e-01, -6.8896e-01, -7.9102e-01, -6.1441e-01]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 22
# tensor([[-1.1007, -0.9201, -0.6888, -0.2291, -1.0525, -0.7599, -1.2523, -0.7128,
#          -0.2122,  0.7183, -0.4422,  0.0304, -0.5381,  0.2685],
#         [ 1.4928,  0.2064, -0.0144, -0.3447, -0.0948, -0.3756, -0.4762, -0.3873,
#          -0.3651, -0.4253, -0.1021, -0.1858,  0.1559,  0.3425]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 23
# tensor([[ 4.2141e-01, -1.1954e+00,  4.1735e-04,  3.8208e-01, -7.8389e-01,
#          -7.1811e-01, -4.6551e-01, -6.3359e-01, -7.8729e-01, -7.2922e-01,
#          -8.5732e-01, -7.5331e-01, -8.2815e-01, -7.3399e-01],
#         [-1.2929e+00, -1.1954e+00, -8.2282e-01, -8.0922e-01, -4.2202e-01,
#          -2.5187e-01, -3.6075e-01, -2.0194e-01, -8.2776e-01, -8.0143e-01,
#          -9.4604e-01, -8.9120e-01, -1.1012e+00, -8.3854e-01]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 24
# tensor([[-1.2929, -1.1954, -0.9894, -0.8729, -1.1688, -0.9721, -0.8883, -0.7345,
#          -0.8390, -0.7811, -0.9099, -0.8307, -0.9524, -0.7708],
#         [ 1.4928,  1.3746,  8.9518,  3.7875,  6.6666,  3.6543, -0.6823, -0.8788,
#          -0.3765, -0.5304, -0.8602, -0.8174,  0.0464, -0.4244]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 25
# tensor([[-0.5964,  0.0896,  0.1961,  0.4481, -0.4427, -0.2572,  0.3139,  0.4779,
#           0.1560,  0.1616, -0.0914, -0.2583,  0.7429,  0.7991],
#         [-0.7493, -0.6683, -0.6703, -0.5355, -0.4085, -0.3411, -0.6355, -0.5295,
#          -0.5648, -0.5672, -0.7493, -0.7584, -0.5759, -0.5094]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 26
# tensor([[-0.4970, -0.8283,  0.1966,  0.8532,  0.0793,  0.2667, -0.8631, -0.5125,
#          -0.6778, -0.6962, -0.5481, -0.5971, -0.3570, -0.5402],
#         [ 0.0660, -0.6683, -0.1510, -0.0719, -0.2505, -0.2159, -0.4591, -0.3437,
#          -0.6755, -0.6475, -0.5248, -0.5882, -0.4155, -0.3004]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 27
# tensor([[ 0.4798, -0.7282,  0.5164,  0.9416, -0.0899, -0.2312,  0.1747,  1.2661,
#          -0.1115,  0.5492, -0.3587, -0.2247, -0.1423,  0.7271],
#         [ 0.2990, -0.4611, -0.2581, -0.4262, -0.8191, -0.8523, -0.9052, -0.8179,
#          -0.4059, -0.4168, -0.6283, -0.7823, -0.9038, -0.7005]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 28
# tensor([[-0.3417, -0.4047, -0.5237, -0.4033, -0.5285, -0.5970, -0.3998, -0.4029,
#          -0.5342, -0.5336, -0.3154, -0.3362, -0.5484, -0.3323],
#         [ 0.2990,  0.2732, -0.1097, -0.2574,  0.6383,  0.6614,  0.6178,  0.2592,
#          -0.0034,  0.0620,  0.4048,  0.2630,  0.1431, -0.0209]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 29
# tensor([[ 0.8738,  0.8035,  0.9178,  0.4412,  1.5170,  1.2266,  0.1627,  0.3087,
#           1.9890,  1.2391,  3.4374,  2.8480,  1.1863,  0.7718],
#         [ 0.2990,  0.8606,  0.4505,  0.3048,  0.0165, -0.1343,  0.0526, -0.2222,
#           0.2746,  0.0557,  0.0511, -0.1444,  0.1719, -0.1182]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 30
# tensor([[ 3.3499,  1.5174,  2.2123,  0.4797,  0.2761, -0.3876,  0.7626, -0.2346,
#          -0.0667, -0.4490, -0.0448, -0.0090,  0.6949,  0.1062],
#         [-0.7493, -0.2729, -0.6620, -0.4658, -0.4370, -0.2564, -0.7388, -0.6635,
#          -0.5210, -0.5256, -0.5481, -0.4778, -0.5351, -0.3781]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 31
# tensor([[ 0.2990,  0.2732, -0.5753, -0.7136, -0.1010, -0.5745, -0.2010,  0.0436,
#           1.8308,  3.0307,  1.1550,  1.4817,  0.7110,  1.2654],
#         [ 1.3381,  2.0885,  1.0827,  0.5797,  0.7098,  0.0262,  0.9210,  0.0819,
#           1.5076,  0.5373,  0.7139, -0.0866,  0.8056,  0.0623]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 32
# tensor([[-0.8852, -0.4432, -0.6300, -0.2697, -0.7181, -0.7012, -0.7880, -0.5468,
#          -0.6576, -0.5991, -0.4486, -0.5268, -0.4849, -0.4476],
#         [ 1.0172, -0.9318, -0.0151, -0.1943,  0.2688,  0.1720, -0.0145, -0.2299,
#          -0.7527, -0.6653, -0.7678, -0.6554, -0.8659, -0.6300]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 33
# tensor([[ 1.9571,  1.8029,  1.5139,  0.5499,  1.8699,  0.7456,  0.9203,  0.2179,
#           0.7530,  0.2620,  1.5984,  0.7219,  0.8301,  0.4395],
#         [ 1.3381,  0.8035,  0.8082,  0.1656,  1.3111,  0.7882,  1.9438,  0.5615,
#           0.5567,  0.3530, -0.1040, -0.4051,  0.0621, -0.1213]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 34
# tensor([[-0.7864, -0.8528, -0.1166,  0.5349, -0.5613, -0.0577, -0.6367, -0.0524,
#          -0.6397, -0.3773, -0.3425, -0.4352, -0.6314, -0.2728],
#         [ 0.2071,  0.0896, -0.2436, -0.3786, -0.2936, -0.2713,  0.9316,  1.1102,
#          -0.2298, -0.3971,  0.5393,  0.5618,  1.1986,  1.0261]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 35
# tensor([[ 0.4737, -0.0093, -0.2322, -0.3248,  0.0411, -0.2831, -0.0546, -0.2161,
#          -0.4701, -0.5296, -0.1552, -0.3433, -0.0713,  0.0021],
#         [-1.2929, -1.1954, -0.8084, -0.8357, -0.8672, -0.9159, -0.9672, -0.8318,
#          -0.7880, -0.7467, -0.7892, -0.7440, -0.9452, -0.7427]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 36
# tensor([[ 0.3785,  1.7804, -0.3969, -0.3909, -0.1640,  0.2335, -0.0410, -0.0233,
#           2.7856,  3.2278,  3.3387,  3.6924,  2.0490,  1.8049],
#         [-1.2929, -1.1954, -0.8286, -0.8229, -0.6754, -0.7591, -0.9266, -0.8011,
#          -0.7509, -0.7224, -0.4893, -0.5854, -0.7670, -0.6546]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 37
# tensor([[-0.2799, -0.2609, -0.5932, -0.4915, -0.2212,  0.4703, -0.7057, -0.4946,
#          -0.6036, -0.5725,  0.1763,  0.4767, -0.5230, -0.2881],
#         [ 1.1833,  0.2324,  0.4095,  0.0558,  0.7873,  0.3671,  1.5725,  0.6202,
#           0.1123,  0.0720,  0.1174,  0.0588,  0.3840,  0.0752]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 38
# tensor([[ 1.2143,  0.6983,  1.7050,  0.9275,  6.3677,  5.4386,  0.1469, -0.0323,
#           0.4407,  0.4474,  0.1504,  0.5321,  0.8483,  0.4840],
#         [-0.9446,  0.4108, -0.3873, -0.3632, -0.7826, -0.8248, -0.6764, -0.2284,
#          -0.0643,  0.1015, -0.2946, -0.0451, -0.0565,  0.1422]])
# tensor([[0.],
#         [0.]])
#
#
#  Epoch = 1
# ------------------------------
# bat_idx = 0
# tensor([[ 1.8023,  0.8035,  1.6817,  1.0111,  1.0034,  0.1335,  1.5408,  0.1130,
#           0.6986,  0.3620, -0.1068, -0.3771,  0.4216,  0.0098],
#         [-0.0266, -0.9618, -0.3247, -0.3172,  0.8742,  1.5827, -0.2514, -0.3559,
#          -0.7890, -0.7129, -0.5652, -0.4260, -1.0537, -0.7688]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 1
# tensor([[ 0.2990,  0.2732, -0.5753, -0.7136, -0.1010, -0.5745, -0.2010,  0.0436,
#           1.8308,  3.0307,  1.1550,  1.4817,  0.7110,  1.2654],
#         [ 1.2143,  0.6983,  1.7050,  0.9275,  6.3677,  5.4386,  0.1469, -0.0323,
#           0.4407,  0.4474,  0.1504,  0.5321,  0.8483,  0.4840]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 2
# tensor([[ 0.8738,  0.8035,  0.9178,  0.4412,  1.5170,  1.2266,  0.1627,  0.3087,
#           1.9890,  1.2391,  3.4374,  2.8480,  1.1863,  0.7718],
#         [-0.7493, -0.6683, -0.6703, -0.5355, -0.4085, -0.3411, -0.6355, -0.5295,
#          -0.5648, -0.5672, -0.7493, -0.7584, -0.5759, -0.5094]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 3
# tensor([[-1.2929, -1.1954, -1.0058, -0.8590, -1.0906, -0.9732, -1.1785, -0.8222,
#          -0.8753, -0.7798, -0.9283, -0.8210, -1.0470, -0.7732],
#         [-1.2929, -1.1954, -0.8675, -0.8409, -0.9023, -0.8332, -1.2218, -0.8875,
#          -0.8771, -0.7876, -0.7914, -0.7954, -0.9614, -0.7678]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 4
# tensor([[ 0.2990,  1.0075, -0.0731, -0.3345, -0.9726, -0.8630, -0.9110, -0.7449,
#           0.0445, -0.2696, -0.3897, -0.1362, -0.2042,  0.0083],
#         [ 0.2071,  0.0896, -0.2436, -0.3786, -0.2936, -0.2713,  0.9316,  1.1102,
#          -0.2298, -0.3971,  0.5393,  0.5618,  1.1986,  1.0261]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 5
# tensor([[-1.0786, -0.5529, -0.7462, -0.5316, -0.7131, -0.4571, -0.8301, -0.5142,
#          -0.5519, -0.5742, -0.5052, -0.5436, -0.6540, -0.6560],
#         [-0.8643, -0.4047, -0.6814, -0.8033, -0.3733, -0.6041, -0.7150, -0.6508,
#          -0.6330, -0.6157, -0.7882, -0.6558, -0.7229, -0.5778]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 6
# tensor([[-0.0266, -0.0272,  0.3612,  0.7005,  0.4742,  0.2032,  0.2786,  0.1418,
#          -0.3854, -0.3436, -0.4564, -0.5992, -0.2934, -0.3461],
#         [-1.2929, -1.1954, -0.8228, -0.8092, -0.4220, -0.2519, -0.3607, -0.2019,
#          -0.8278, -0.8014, -0.9460, -0.8912, -1.1012, -0.8385]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 7
# tensor([[-0.7493, -0.5365, -0.7442, -0.6360, -0.4533, -0.2577, -0.6731, -0.5492,
#          -0.6036, -0.5717, -0.7298, -0.7058, -0.7047, -0.5442],
#         [ 1.4928,  1.2393,  3.0986,  3.1787,  3.6842,  3.6688,  3.8953,  2.0780,
#          -0.2441, -0.4188,  1.1128,  2.0565,  0.5196,  0.9542]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 8
# tensor([[ 0.4095,  1.3746,  0.5515,  0.3193, -0.3277, -0.5140,  0.2017, -0.2235,
#           0.8701,  0.3451,  0.1212, -0.3545,  0.5775, -0.1905],
#         [-0.3417, -0.5365, -0.5488, -0.5932, -0.4525, -0.5367, -0.3475, -0.2912,
#          -0.5751, -0.5040, -0.5382, -0.5870, -0.5319, -0.5611]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 9
# tensor([[-0.8643,  0.0896, -0.1861,  0.4611, -0.6988, -0.6980, -0.8082, -0.5862,
#          -0.0733,  0.2162, -0.3389, -0.5668, -0.6478, -0.6178],
#         [-0.9446,  0.4108, -0.3873, -0.3632, -0.7826, -0.8248, -0.6764, -0.2284,
#          -0.0643,  0.1015, -0.2946, -0.0451, -0.0565,  0.1422]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 10
# tensor([[-0.0548, -0.9099,  0.1392,  0.1645,  0.5119,  0.6341,  0.6929,  0.2395,
#          -0.7243, -0.7077, -0.6610, -0.7337, -0.7119, -0.5614],
#         [ 1.3381,  2.0885,  1.0827,  0.5797,  0.7098,  0.0262,  0.9210,  0.0819,
#           1.5076,  0.5373,  0.7139, -0.0866,  0.8056,  0.0623]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 11
# tensor([[-0.8852, -0.4432, -0.6300, -0.2697, -0.7181, -0.7012, -0.7880, -0.5468,
#          -0.6576, -0.5991, -0.4486, -0.5268, -0.4849, -0.4476],
#         [-1.2929, -1.1954, -0.9894, -0.8729, -1.1688, -0.9721, -0.8883, -0.7345,
#          -0.8390, -0.7811, -0.9099, -0.8307, -0.9524, -0.7708]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 12
# tensor([[ 0.1000, -1.1954,  0.4603, -0.1284, -0.2524, -0.6453,  0.2940, -0.2774,
#          -0.5081, -0.4088, -0.7996, -0.7509, -0.8587, -0.6410],
#         [ 0.2990,  0.8606,  0.4505,  0.3048,  0.0165, -0.1343,  0.0526, -0.2222,
#           0.2746,  0.0557,  0.0511, -0.1444,  0.1719, -0.1182]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 13
# tensor([[-0.7864, -0.7282, -0.5795, -0.5816, -0.4487, -0.1423, -0.6829, -0.4085,
#          -0.6434, -0.4151, -0.3028,  0.5056, -0.1854,  0.5048],
#         [ 0.9357,  0.1572,  0.5389,  0.4613,  0.0572,  0.1882,  1.8196,  2.3665,
#           0.1473,  0.2180, -0.1883,  0.3658,  1.2870,  2.0409]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 14
# tensor([[ 0.0660, -0.6683, -0.1510, -0.0719, -0.2505, -0.2159, -0.4591, -0.3437,
#          -0.6755, -0.6475, -0.5248, -0.5882, -0.4155, -0.3004],
#         [ 3.3499,  1.5174,  2.2123,  0.4797,  0.2761, -0.3876,  0.7626, -0.2346,
#          -0.0667, -0.4490, -0.0448, -0.0090,  0.6949,  0.1062]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 15
# tensor([[ 1.8023, -0.3388,  0.3740, -0.0952, -0.0407, -0.3136,  0.9260,  0.3264,
#          -0.3406, -0.1650, -0.6769, -0.6527, -0.4202, -0.5247],
#         [-1.2929, -1.1954, -0.8770, -0.8343, -0.6476, -0.6524, -0.8210, -0.7621,
#          -0.8008, -0.7601, -0.5056, -0.6260, -0.9854, -0.7108]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 16
# tensor([[ 0.4798, -0.0272,  0.3931,  0.4468,  0.1833, -0.3037,  0.2067,  0.0324,
#          -0.3592, -0.4319, -0.4427, -0.4015, -0.3588, -0.3747],
#         [-1.2929, -1.1954, -0.8158, -0.8110, -1.0413, -0.9259, -0.9175, -0.7767,
#          -0.6590, -0.6901, -0.7704, -0.7257, -0.7440, -0.6699]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 17
# tensor([[ 1.3381,  0.8035,  0.8082,  0.1656,  1.3111,  0.7882,  1.9438,  0.5615,
#           0.5567,  0.3530, -0.1040, -0.4051,  0.0621, -0.1213],
#         [-0.0072, -0.3388,  0.5628,  1.8037,  0.6772,  0.7048,  1.1893,  0.7828,
#           0.0925,  0.8427, -0.3094,  0.2658,  0.0530,  0.1797]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 18
# tensor([[-0.7493, -0.2729, -0.6620, -0.4658, -0.4370, -0.2564, -0.7388, -0.6635,
#          -0.5210, -0.5256, -0.5481, -0.4778, -0.5351, -0.3781],
#         [-1.2929, -1.1954, -0.8084, -0.8357, -0.8672, -0.9159, -0.9672, -0.8318,
#          -0.7880, -0.7467, -0.7892, -0.7440, -0.9452, -0.7427]])
# tensor([[1.],
#         [0.]])
# ------------------------------
# bat_idx = 19
# tensor([[ 1.4928,  0.2064, -0.0144, -0.3447, -0.0948, -0.3756, -0.4762, -0.3873,
#          -0.3651, -0.4253, -0.1021, -0.1858,  0.1559,  0.3425],
#         [-1.1007, -0.9201, -0.6888, -0.2291, -1.0525, -0.7599, -1.2523, -0.7128,
#          -0.2122,  0.7183, -0.4422,  0.0304, -0.5381,  0.2685]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 20
# tensor([[-1.2929, -1.1954, -0.8151, -0.8276, -0.3972, -0.4387, -1.1284, -0.8043,
#          -0.8490, -0.7764, -0.9526, -0.7400, -0.9971, -0.7576],
#         [-0.5964,  0.0896,  0.1961,  0.4481, -0.4427, -0.2572,  0.3139,  0.4779,
#           0.1560,  0.1616, -0.0914, -0.2583,  0.7429,  0.7991]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 21
# tensor([[ 9.9981e-02,  6.6070e-01, -1.1139e-01, -3.8847e-02, -2.8407e-01,
#          -2.3652e-01,  2.9636e-01, -1.5173e-01,  1.6314e-01, -5.9253e-04,
#          -1.4074e-01, -3.8159e-01,  1.1885e+00,  9.1617e-01],
#         [-3.4165e-01, -4.0466e-01, -5.2365e-01, -4.0334e-01, -5.2845e-01,
#          -5.9703e-01, -3.9978e-01, -4.0288e-01, -5.3422e-01, -5.3357e-01,
#          -3.1543e-01, -3.3617e-01, -5.4842e-01, -3.3235e-01]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 22
# tensor([[ 0.2990, -0.4611, -0.2581, -0.4262, -0.8191, -0.8523, -0.9052, -0.8179,
#          -0.4059, -0.4168, -0.6283, -0.7823, -0.9038, -0.7005],
#         [-0.7493, -0.1411, -0.6569, -0.5158, -0.6767, -0.5921, -1.0360, -0.7306,
#          -0.3253, -0.2923, -0.5004, -0.5705, -0.3669, -0.2867]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 23
# tensor([[-0.1786, -1.1954, -0.5677, -0.6007,  0.3166,  0.6409, -0.9676, -0.7870,
#          -0.8176, -0.7609, -0.8697, -0.8402, -0.8886, -0.7622],
#         [-0.2482, -0.2317, -0.6988, -0.7444, -0.5643, -0.6488, -0.8372, -0.7479,
#          -0.4829, -0.5579, -0.7219, -0.7797, -0.5980, -0.5091]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 24
# tensor([[-0.8852,  0.7815, -0.6790, -0.6405, -0.4656, -0.4067, -0.4534, -0.2030,
#          -0.0307, -0.1394,  0.9512,  0.9330,  0.2251, -0.0338],
#         [-1.2929, -1.1954, -0.8833, -0.8044, -0.7867, -0.8148, -1.0770, -0.7700,
#          -0.8258, -0.7654, -0.9285, -0.8162, -0.9793, -0.7957]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 25
# tensor([[ 0.1000,  2.6596,  2.2306,  1.6113,  0.7616,  0.8243,  2.3605,  0.7721,
#           2.8374,  1.8003,  0.3553,  0.2982,  2.2448,  0.8041],
#         [-0.8286, -0.7671, -0.8146, -0.6640, -0.6354, -0.2387, -0.4126,  0.1661,
#          -0.8269, -0.7238, -0.7103, -0.6890, -0.7910, -0.6144]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 26
# tensor([[ 1.4928,  1.3746,  8.9518,  3.7875,  6.6666,  3.6543, -0.6823, -0.8788,
#          -0.3765, -0.5304, -0.8602, -0.8174,  0.0464, -0.4244],
#         [ 1.1833,  0.2324,  0.4095,  0.0558,  0.7873,  0.3671,  1.5725,  0.6202,
#           0.1123,  0.0720,  0.1174,  0.0588,  0.3840,  0.0752]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 27
# tensor([[ 0.4798, -0.7282,  0.5164,  0.9416, -0.0899, -0.2312,  0.1747,  1.2661,
#          -0.1115,  0.5492, -0.3587, -0.2247, -0.1423,  0.7271],
#         [ 0.2266, -0.7282, -0.0993, -0.0215,  0.5663,  0.9972, -0.3605, -0.1447,
#          -0.7348, -0.6718, -0.5428, -0.4971, -0.6994, -0.5349]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 28
# tensor([[ 0.3785,  1.7804, -0.3969, -0.3909, -0.1640,  0.2335, -0.0410, -0.0233,
#           2.7856,  3.2278,  3.3387,  3.6924,  2.0490,  1.8049],
#         [-0.2214,  1.8029,  0.1309,  0.5541,  0.0338,  0.2984,  0.1606,  0.3436,
#           0.7455,  0.6468,  0.2211,  0.3180,  0.8275,  0.3193]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 29
# tensor([[-1.2929, -0.9447, -0.8871, -0.8436, -0.9196, -0.8857, -1.0134, -0.8277,
#          -0.7103, -0.4272, -0.7944, -0.7526, -0.8189, -0.6153],
#         [-0.4970, -0.8283,  0.1966,  0.8532,  0.0793,  0.2667, -0.8631, -0.5125,
#          -0.6778, -0.6962, -0.5481, -0.5971, -0.3570, -0.5402]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 30
# tensor([[ 4.2141e-01, -1.1954e+00,  4.1735e-04,  3.8208e-01, -7.8389e-01,
#          -7.1811e-01, -4.6551e-01, -6.3359e-01, -7.8729e-01, -7.2922e-01,
#          -8.5732e-01, -7.5331e-01, -8.2815e-01, -7.3399e-01],
#         [ 4.7985e-01, -2.6088e-01,  1.2299e+00,  2.0711e+00,  1.3942e+00,
#           2.0318e+00,  2.4702e+00,  2.8692e+00, -4.6245e-01, -5.0481e-01,
#          -4.7608e-01, -5.9269e-01, -7.1883e-01, -6.7014e-01]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 31
# tensor([[ 0.8738,  1.0890,  2.4391,  2.3642,  3.7356,  3.5329,  3.0257,  1.3945,
#           0.6252,  0.6184,  0.3754,  0.4678,  0.6384,  0.5851],
#         [ 1.0172, -0.9318, -0.0151, -0.1943,  0.2688,  0.1720, -0.0145, -0.2299,
#          -0.7527, -0.6653, -0.7678, -0.6554, -0.8659, -0.6300]])
# tensor([[0.],
#         [1.]])
# ------------------------------
# bat_idx = 32
# tensor([[-1.2929, -1.1954, -0.8286, -0.8229, -0.6754, -0.7591, -0.9266, -0.8011,
#          -0.7509, -0.7224, -0.4893, -0.5854, -0.7670, -0.6546],
#         [ 0.4737, -0.0093, -0.2322, -0.3248,  0.0411, -0.2831, -0.0546, -0.2161,
#          -0.4701, -0.5296, -0.1552, -0.3433, -0.0713,  0.0021]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 33
# tensor([[-0.7864, -0.8528, -0.1166,  0.5349, -0.5613, -0.0577, -0.6367, -0.0524,
#          -0.6397, -0.3773, -0.3425, -0.4352, -0.6314, -0.2728],
#         [-0.0548, -0.0532, -0.4213, -0.6120, -0.1760, -0.2939, -0.0867, -0.2050,
#          -0.4306, -0.4392, -0.2021, -0.1434, -0.4942, -0.4095]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 34
# tensor([[ 0.4737,  1.1769,  0.8836,  0.8842,  0.8299,  1.3087,  1.0070,  1.2870,
#           0.0872, -0.0886,  0.2764,  0.4441,  0.8312,  0.6254],
#         [-1.2929, -1.1954, -0.7804, -0.8402, -0.6429, -0.7256, -0.5100, -0.7376,
#          -0.7973, -0.7825, -0.7008, -0.7904, -0.8537, -0.6529]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 35
# tensor([[-0.2799, -0.2609, -0.5932, -0.4915, -0.2212,  0.4703, -0.7057, -0.4946,
#          -0.6036, -0.5725,  0.1763,  0.4767, -0.5230, -0.2881],
#         [-0.8852, -1.1954, -0.7871, -0.6727, -0.9461, -0.8720, -0.9292, -0.6732,
#          -0.7986, -0.7617, -0.8101, -0.7829, -0.8094, -0.7275]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 36
# tensor([[ 1.9571,  1.8029,  1.5139,  0.5499,  1.8699,  0.7456,  0.9203,  0.2179,
#           0.7530,  0.2620,  1.5984,  0.7219,  0.8301,  0.4395],
#         [ 0.0660, -0.2729, -0.3380, -0.3721, -0.2711, -0.3924, -0.1415, -0.0577,
#          -0.6147, -0.6491, -0.3772, -0.4407, -0.0657,  0.1042]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 37
# tensor([[ 0.2990,  0.2732, -0.1097, -0.2574,  0.6383,  0.6614,  0.6178,  0.2592,
#          -0.0034,  0.0620,  0.4048,  0.2630,  0.1431, -0.0209],
#         [-0.7357, -0.9249, -0.6782, -0.4665, -0.5635, -0.3115, -0.8646, -0.5660,
#          -0.8531, -0.7362, -0.8524, -0.6610, -0.8691, -0.6681]])
# tensor([[0.],
#         [0.]])
# ------------------------------
# bat_idx = 38
# tensor([[ 0.2071, -0.3388, -0.5344, -0.6257, -0.3667, -0.5465, -0.4988, -0.2853,
#          -0.5953, -0.5711, -0.6644, -0.7111, -0.5230, -0.6154],
#         [-0.8852,  0.9133, -0.7464, -0.6571, -0.6514, -0.8097, -0.6532, -0.5272,
#          -0.0945, -0.2795,  0.7387,  0.4902,  0.6513,  0.3736]])
# tensor([[0.],
#         [0.]])
# End test

# %%
# Hyper-parameters 
input_size = 14 
hidden_size1 = 25
hidden_size2 = 25
num_classes = 1
num_epochs = 100
batch_size = 50
learning_rate = 0.001

# %%
## Load the data
src1 = '/Users/david/Desktop/PCM_train.csv'
src2 = '/Users/david/Desktop/PCM_test.csv'

# get the training and testing dataset
train_dataset = PCMDataset(src1)
test_dataset = PCMDataset(src2)

# DataLoader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

examples = iter(test_loader)
example_data, example_targets = examples.next()

# %%
# Fully connected neural network with two hidden layer
class Net(torch.nn.Module):
  def __init__(self, input_size, hidden_size1, hidden_size2,num_classes):
    super(Net, self).__init__()
    self.hid1 = torch.nn.Linear(input_size, hidden_size1)  # 4-(8-8)-1
    self.hid2 = torch.nn.Linear(hidden_size1, hidden_size2)
    self.oupt = torch.nn.Linear(hidden_size2, num_classes)

    torch.nn.init.xavier_uniform_(self.hid1.weight)
    torch.nn.init.zeros_(self.hid1.bias)
    torch.nn.init.xavier_uniform_(self.hid2.weight)
    torch.nn.init.zeros_(self.hid2.bias)
    torch.nn.init.xavier_uniform_(self.oupt.weight)
    torch.nn.init.zeros_(self.oupt.bias)

  def forward(self, x):
    z = torch.tanh(self.hid1(x)) 
    z = torch.tanh(self.hid2(z))
    z = torch.sigmoid(self.oupt(z))
    return z

model = Net(input_size, hidden_size1, hidden_size2, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
    epoch_loss = 0.0  # sum of batch losses
    for (batch_idx, batch) in enumerate(train_loader):
        X = batch['predictors']  # [20,14]  inputs
        Y = batch['target']      # [20,1]  targets

        # Forward pass
        oupt = model(X)            # [20,1]  computed
        loss_val = criterion(oupt, Y)   # a tensor
        epoch_loss += loss_val.sum().item()  # accumulate

        # Backward and optimize
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()
        
        if True:  
            print("epoch = %4d   loss = %0.4f" % (epoch, epoch_loss))

print("Done ")
# Out:
# epoch =    0   loss = 0.6941
# epoch =    0   loss = 1.3978
# epoch =    0   loss = 2.0777
# epoch =    0   loss = 2.7726
# epoch =    0   loss = 3.4592
# epoch =    1   loss = 0.6710
# epoch =    1   loss = 1.3467
# epoch =    1   loss = 2.0168
# epoch =    1   loss = 2.6901
# epoch =    1   loss = 3.3218
# epoch =    2   loss = 0.6472
# epoch =    2   loss = 1.2972
# epoch =    2   loss = 1.9451
# epoch =    2   loss = 2.5716
# epoch =    2   loss = 3.2241
# epoch =    3   loss = 0.6523
# epoch =    3   loss = 1.2672
# epoch =    3   loss = 1.8815
# epoch =    3   loss = 2.5008
# epoch =    3   loss = 3.1126
# epoch =    4   loss = 0.6220
# epoch =    4   loss = 1.2078
# epoch =    4   loss = 1.7961
# epoch =    4   loss = 2.4184
# epoch =    4   loss = 3.0164
# epoch =    5   loss = 0.6107
# epoch =    5   loss = 1.1862
# epoch =    5   loss = 1.7391
# epoch =    5   loss = 2.3155
# epoch =    5   loss = 2.9362
# epoch =    6   loss = 0.5814
# epoch =    6   loss = 1.1370
# epoch =    6   loss = 1.7105
# epoch =    6   loss = 2.2687
# epoch =    6   loss = 2.8333
# epoch =    7   loss = 0.5646
# epoch =    7   loss = 1.1101
# epoch =    7   loss = 1.6379
# epoch =    7   loss = 2.1887
# epoch =    7   loss = 2.7466
# epoch =    8   loss = 0.5108
# epoch =    8   loss = 1.0817
# epoch =    8   loss = 1.6229
# epoch =    8   loss = 2.1143
# epoch =    8   loss = 2.6638
# epoch =    9   loss = 0.5255
# epoch =    9   loss = 1.0412
# epoch =    9   loss = 1.5291
# epoch =    9   loss = 2.0543
# epoch =    9   loss = 2.5827
# epoch =   10   loss = 0.5071
# epoch =   10   loss = 1.0155
# epoch =   10   loss = 1.5210
# epoch =   10   loss = 1.9986
# epoch =   10   loss = 2.4783
# epoch =   11   loss = 0.5022
# epoch =   11   loss = 0.9952
# epoch =   11   loss = 1.4806
# epoch =   11   loss = 1.9453
# epoch =   11   loss = 2.3882
# epoch =   12   loss = 0.4724
# epoch =   12   loss = 0.9716
# epoch =   12   loss = 1.3733
# epoch =   12   loss = 1.8446
# epoch =   12   loss = 2.3327
# epoch =   13   loss = 0.4908
# epoch =   13   loss = 0.9157
# epoch =   13   loss = 1.3882
# epoch =   13   loss = 1.8005
# epoch =   13   loss = 2.2394
# epoch =   14   loss = 0.4475
# epoch =   14   loss = 0.9260
# epoch =   14   loss = 1.3265
# epoch =   14   loss = 1.7214
# epoch =   14   loss = 2.1818
# epoch =   15   loss = 0.4667
# epoch =   15   loss = 0.8589
# epoch =   15   loss = 1.2714
# epoch =   15   loss = 1.6845
# epoch =   15   loss = 2.1016
# epoch =   16   loss = 0.4280
# epoch =   16   loss = 0.8444
# epoch =   16   loss = 1.2299
# epoch =   16   loss = 1.6341
# epoch =   16   loss = 2.0281
# epoch =   17   loss = 0.3465
# epoch =   17   loss = 0.7588
# epoch =   17   loss = 1.1277
# epoch =   17   loss = 1.5325
# epoch =   17   loss = 2.0053
# epoch =   18   loss = 0.3637
# epoch =   18   loss = 0.7292
# epoch =   18   loss = 1.1233
# epoch =   18   loss = 1.4653
# epoch =   18   loss = 1.9634
# epoch =   19   loss = 0.3944
# epoch =   19   loss = 0.7992
# epoch =   19   loss = 1.1527
# epoch =   19   loss = 1.4969
# epoch =   19   loss = 1.8646
# epoch =   20   loss = 0.2919
# epoch =   20   loss = 0.6060
# epoch =   20   loss = 1.0665
# epoch =   20   loss = 1.4689
# epoch =   20   loss = 1.8209
# epoch =   21   loss = 0.3876
# epoch =   21   loss = 0.7239
# epoch =   21   loss = 1.0662
# epoch =   21   loss = 1.4533
# epoch =   21   loss = 1.7609
# epoch =   22   loss = 0.3304
# epoch =   22   loss = 0.6674
# epoch =   22   loss = 0.9580
# epoch =   22   loss = 1.3911
# epoch =   22   loss = 1.7593
# epoch =   23   loss = 0.3867
# epoch =   23   loss = 0.7901
# epoch =   23   loss = 1.1718
# epoch =   23   loss = 1.3748
# epoch =   23   loss = 1.7150
# epoch =   24   loss = 0.3879
# epoch =   24   loss = 0.6775
# epoch =   24   loss = 0.9990
# epoch =   24   loss = 1.3848
# epoch =   24   loss = 1.6678
# epoch =   25   loss = 0.3266
# epoch =   25   loss = 0.6600
# epoch =   25   loss = 0.9692
# epoch =   25   loss = 1.3459
# epoch =   25   loss = 1.6546
# epoch =   26   loss = 0.3097
# epoch =   26   loss = 0.7465
# epoch =   26   loss = 1.0611
# epoch =   26   loss = 1.3194
# epoch =   26   loss = 1.6370
# epoch =   27   loss = 0.3051
# epoch =   27   loss = 0.6807
# epoch =   27   loss = 0.9677
# epoch =   27   loss = 1.2610
# epoch =   27   loss = 1.6463
# epoch =   28   loss = 0.3246
# epoch =   28   loss = 0.5800
# epoch =   28   loss = 0.9168
# epoch =   28   loss = 1.3001
# epoch =   28   loss = 1.6040
# epoch =   29   loss = 0.2845
# epoch =   29   loss = 0.5829
# epoch =   29   loss = 0.8354
# epoch =   29   loss = 1.2473
# epoch =   29   loss = 1.6115
# epoch =   30   loss = 0.1936
# epoch =   30   loss = 0.6573
# epoch =   30   loss = 0.9234
# epoch =   30   loss = 1.1661
# epoch =   30   loss = 1.6396
# epoch =   31   loss = 0.3557
# epoch =   31   loss = 0.7053
# epoch =   31   loss = 1.0236
# epoch =   31   loss = 1.3369
# epoch =   31   loss = 1.5256
# epoch =   32   loss = 0.2955
# epoch =   32   loss = 0.6167
# epoch =   32   loss = 0.9309
# epoch =   32   loss = 1.2773
# epoch =   32   loss = 1.5421
# epoch =   33   loss = 0.2897
# epoch =   33   loss = 0.6632
# epoch =   33   loss = 0.8707
# epoch =   33   loss = 1.2502
# epoch =   33   loss = 1.5518
# epoch =   34   loss = 0.2687
# epoch =   34   loss = 0.6153
# epoch =   34   loss = 0.9706
# epoch =   34   loss = 1.2886
# epoch =   34   loss = 1.5089
# epoch =   35   loss = 0.3649
# epoch =   35   loss = 0.5907
# epoch =   35   loss = 0.9126
# epoch =   35   loss = 1.2377
# epoch =   35   loss = 1.5220
# epoch =   36   loss = 0.2725
# epoch =   36   loss = 0.5634
# epoch =   36   loss = 0.9629
# epoch =   36   loss = 1.2563
# epoch =   36   loss = 1.5004
# epoch =   37   loss = 0.4202
# epoch =   37   loss = 0.7340
# epoch =   37   loss = 1.0794
# epoch =   37   loss = 1.2694
# epoch =   37   loss = 1.4853
# epoch =   38   loss = 0.3266
# epoch =   38   loss = 0.6121
# epoch =   38   loss = 0.9931
# epoch =   38   loss = 1.2828
# epoch =   38   loss = 1.4613
# epoch =   39   loss = 0.2617
# epoch =   39   loss = 0.5497
# epoch =   39   loss = 0.9236
# epoch =   39   loss = 1.1791
# epoch =   39   loss = 1.5235
# epoch =   40   loss = 0.2377
# epoch =   40   loss = 0.5507
# epoch =   40   loss = 0.8577
# epoch =   40   loss = 1.2454
# epoch =   40   loss = 1.4688
# epoch =   41   loss = 0.3068
# epoch =   41   loss = 0.5473
# epoch =   41   loss = 0.8774
# epoch =   41   loss = 1.2590
# epoch =   41   loss = 1.4442
# epoch =   42   loss = 0.2907
# epoch =   42   loss = 0.5955
# epoch =   42   loss = 0.9476
# epoch =   42   loss = 1.1699
# epoch =   42   loss = 1.4878
# epoch =   43   loss = 0.3163
# epoch =   43   loss = 0.6500
# epoch =   43   loss = 0.9220
# epoch =   43   loss = 1.2128
# epoch =   43   loss = 1.4545
# epoch =   44   loss = 0.2725
# epoch =   44   loss = 0.5310
# epoch =   44   loss = 0.7891
# epoch =   44   loss = 1.0980
# epoch =   44   loss = 1.5210
# epoch =   45   loss = 0.3028
# epoch =   45   loss = 0.6305
# epoch =   45   loss = 0.8212
# epoch =   45   loss = 1.2225
# epoch =   45   loss = 1.4345
# epoch =   46   loss = 0.2826
# epoch =   46   loss = 0.5321
# epoch =   46   loss = 0.8648
# epoch =   46   loss = 1.1622
# epoch =   46   loss = 1.4533
# epoch =   47   loss = 0.2749
# epoch =   47   loss = 0.5153
# epoch =   47   loss = 0.9380
# epoch =   47   loss = 1.1499
# epoch =   47   loss = 1.4542
# epoch =   48   loss = 0.2440
# epoch =   48   loss = 0.5666
# epoch =   48   loss = 0.9790
# epoch =   48   loss = 1.2357
# epoch =   48   loss = 1.4022
# epoch =   49   loss = 0.2326
# epoch =   49   loss = 0.4663
# epoch =   49   loss = 0.8095
# epoch =   49   loss = 1.0704
# epoch =   49   loss = 1.4949
# epoch =   50   loss = 0.3581
# epoch =   50   loss = 0.6892
# epoch =   50   loss = 0.9130
# epoch =   50   loss = 1.2035
# epoch =   50   loss = 1.4072
# epoch =   51   loss = 0.2498
# epoch =   51   loss = 0.5630
# epoch =   51   loss = 0.8347
# epoch =   51   loss = 1.1800
# epoch =   51   loss = 1.4005
# epoch =   52   loss = 0.3096
# epoch =   52   loss = 0.5502
# epoch =   52   loss = 0.8234
# epoch =   52   loss = 1.0642
# epoch =   52   loss = 1.4665
# epoch =   53   loss = 0.2143
# epoch =   53   loss = 0.5320
# epoch =   53   loss = 0.8023
# epoch =   53   loss = 1.1701
# epoch =   53   loss = 1.3905
# epoch =   54   loss = 0.1808
# epoch =   54   loss = 0.4664
# epoch =   54   loss = 0.8653
# epoch =   54   loss = 1.1023
# epoch =   54   loss = 1.4239
# epoch =   55   loss = 0.2652
# epoch =   55   loss = 0.5901
# epoch =   55   loss = 0.8272
# epoch =   55   loss = 1.1285
# epoch =   55   loss = 1.3982
# epoch =   56   loss = 0.3566
# epoch =   56   loss = 0.6011
# epoch =   56   loss = 0.8709
# epoch =   56   loss = 1.1430
# epoch =   56   loss = 1.3824
# epoch =   57   loss = 0.3388
# epoch =   57   loss = 0.7166
# epoch =   57   loss = 0.8992
# epoch =   57   loss = 1.0920
# epoch =   57   loss = 1.4086
# epoch =   58   loss = 0.2451
# epoch =   58   loss = 0.5744
# epoch =   58   loss = 0.8875
# epoch =   58   loss = 1.1517
# epoch =   58   loss = 1.3584
# epoch =   59   loss = 0.4119
# epoch =   59   loss = 0.6056
# epoch =   59   loss = 0.9167
# epoch =   59   loss = 1.1521
# epoch =   59   loss = 1.3521
# epoch =   60   loss = 0.3059
# epoch =   60   loss = 0.5817
# epoch =   60   loss = 0.7611
# epoch =   60   loss = 1.0274
# epoch =   60   loss = 1.4184
# epoch =   61   loss = 0.2464
# epoch =   61   loss = 0.6400
# epoch =   61   loss = 0.8873
# epoch =   61   loss = 1.0379
# epoch =   61   loss = 1.4077
# epoch =   62   loss = 0.2775
# epoch =   62   loss = 0.5198
# epoch =   62   loss = 0.8850
# epoch =   62   loss = 1.1384
# epoch =   62   loss = 1.3412
# epoch =   63   loss = 0.2698
# epoch =   63   loss = 0.5459
# epoch =   63   loss = 0.8394
# epoch =   63   loss = 1.1040
# epoch =   63   loss = 1.3493
# epoch =   64   loss = 0.2171
# epoch =   64   loss = 0.6047
# epoch =   64   loss = 0.9602
# epoch =   64   loss = 1.1110
# epoch =   64   loss = 1.3452
# epoch =   65   loss = 0.2969
# epoch =   65   loss = 0.5656
# epoch =   65   loss = 0.9099
# epoch =   65   loss = 1.1208
# epoch =   65   loss = 1.3232
# epoch =   66   loss = 0.1889
# epoch =   66   loss = 0.5361
# epoch =   66   loss = 0.7712
# epoch =   66   loss = 1.0389
# epoch =   66   loss = 1.3650
# epoch =   67   loss = 0.2591
# epoch =   67   loss = 0.5094
# epoch =   67   loss = 0.7936
# epoch =   67   loss = 1.1216
# epoch =   67   loss = 1.3146
# epoch =   68   loss = 0.3063
# epoch =   68   loss = 0.5368
# epoch =   68   loss = 0.8066
# epoch =   68   loss = 1.1224
# epoch =   68   loss = 1.3062
# epoch =   69   loss = 0.2902
# epoch =   69   loss = 0.5813
# epoch =   69   loss = 0.8337
# epoch =   69   loss = 1.0621
# epoch =   69   loss = 1.3359
# epoch =   70   loss = 0.3826
# epoch =   70   loss = 0.6609
# epoch =   70   loss = 0.9187
# epoch =   70   loss = 1.1158
# epoch =   70   loss = 1.3070
# epoch =   71   loss = 0.2521
# epoch =   71   loss = 0.4726
# epoch =   71   loss = 0.8291
# epoch =   71   loss = 1.0315
# epoch =   71   loss = 1.3347
# epoch =   72   loss = 0.2262
# epoch =   72   loss = 0.4811
# epoch =   72   loss = 0.6927
# epoch =   72   loss = 0.9543
# epoch =   72   loss = 1.3805
# epoch =   73   loss = 0.2368
# epoch =   73   loss = 0.5972
# epoch =   73   loss = 0.7906
# epoch =   73   loss = 1.0967
# epoch =   73   loss = 1.2871
# epoch =   74   loss = 0.3058
# epoch =   74   loss = 0.5913
# epoch =   74   loss = 0.8450
# epoch =   74   loss = 1.0849
# epoch =   74   loss = 1.2812
# epoch =   75   loss = 0.2679
# epoch =   75   loss = 0.4754
# epoch =   75   loss = 0.8524
# epoch =   75   loss = 1.0339
# epoch =   75   loss = 1.3057
# epoch =   76   loss = 0.2820
# epoch =   76   loss = 0.6084
# epoch =   76   loss = 0.8483
# epoch =   76   loss = 1.0760
# epoch =   76   loss = 1.2751
# epoch =   77   loss = 0.2060
# epoch =   77   loss = 0.4290
# epoch =   77   loss = 0.7471
# epoch =   77   loss = 1.0501
# epoch =   77   loss = 1.2824
# epoch =   78   loss = 0.2626
# epoch =   78   loss = 0.4652
# epoch =   78   loss = 0.6513
# epoch =   78   loss = 0.9187
# epoch =   78   loss = 1.3605
# epoch =   79   loss = 0.2780
# epoch =   79   loss = 0.4992
# epoch =   79   loss = 0.7556
# epoch =   79   loss = 0.9672
# epoch =   79   loss = 1.3335
# epoch =   80   loss = 0.2836
# epoch =   80   loss = 0.5147
# epoch =   80   loss = 0.7220
# epoch =   80   loss = 0.8964
# epoch =   80   loss = 1.3616
# epoch =   81   loss = 0.2588
# epoch =   81   loss = 0.5290
# epoch =   81   loss = 0.7347
# epoch =   81   loss = 0.9957
# epoch =   81   loss = 1.2900
# epoch =   82   loss = 0.2065
# epoch =   82   loss = 0.4611
# epoch =   82   loss = 0.7713
# epoch =   82   loss = 1.0267
# epoch =   82   loss = 1.2664
# epoch =   83   loss = 0.2622
# epoch =   83   loss = 0.4683
# epoch =   83   loss = 0.7279
# epoch =   83   loss = 0.9297
# epoch =   83   loss = 1.3324
# epoch =   84   loss = 0.3319
# epoch =   84   loss = 0.5013
# epoch =   84   loss = 0.7574
# epoch =   84   loss = 1.0182
# epoch =   84   loss = 1.2687
# epoch =   85   loss = 0.1817
# epoch =   85   loss = 0.4204
# epoch =   85   loss = 0.6614
# epoch =   85   loss = 0.9423
# epoch =   85   loss = 1.3025
# epoch =   86   loss = 0.2516
# epoch =   86   loss = 0.5226
# epoch =   86   loss = 0.8403
# epoch =   86   loss = 1.0140
# epoch =   86   loss = 1.2573
# epoch =   87   loss = 0.2771
# epoch =   87   loss = 0.4586
# epoch =   87   loss = 0.8057
# epoch =   87   loss = 0.9776
# epoch =   87   loss = 1.2677
# epoch =   88   loss = 0.1528
# epoch =   88   loss = 0.4723
# epoch =   88   loss = 0.8038
# epoch =   88   loss = 1.0092
# epoch =   88   loss = 1.2400
# epoch =   89   loss = 0.2869
# epoch =   89   loss = 0.4183
# epoch =   89   loss = 0.7933
# epoch =   89   loss = 1.0269
# epoch =   89   loss = 1.2252
# epoch =   90   loss = 0.1429
# epoch =   90   loss = 0.4648
# epoch =   90   loss = 0.6668
# epoch =   90   loss = 0.8998
# epoch =   90   loss = 1.2977
# epoch =   91   loss = 0.2011
# epoch =   91   loss = 0.3979
# epoch =   91   loss = 0.6716
# epoch =   91   loss = 0.9996
# epoch =   91   loss = 1.2326
# epoch =   92   loss = 0.2764
# epoch =   92   loss = 0.5237
# epoch =   92   loss = 0.7337
# epoch =   92   loss = 0.9540
# epoch =   92   loss = 1.2556
# epoch =   93   loss = 0.2394
# epoch =   93   loss = 0.4591
# epoch =   93   loss = 0.8080
# epoch =   93   loss = 1.0011
# epoch =   93   loss = 1.2211
# epoch =   94   loss = 0.3127
# epoch =   94   loss = 0.5739
# epoch =   94   loss = 0.8063
# epoch =   94   loss = 1.0390
# epoch =   94   loss = 1.1973
# epoch =   95   loss = 0.2308
# epoch =   95   loss = 0.4294
# epoch =   95   loss = 0.8129
# epoch =   95   loss = 0.9927
# epoch =   95   loss = 1.2120
# epoch =   96   loss = 0.2468
# epoch =   96   loss = 0.5100
# epoch =   96   loss = 0.6924
# epoch =   96   loss = 0.9119
# epoch =   96   loss = 1.2649
# epoch =   97   loss = 0.1408
# epoch =   97   loss = 0.3431
# epoch =   97   loss = 0.6250
# epoch =   97   loss = 1.0044
# epoch =   97   loss = 1.2016
# epoch =   98   loss = 0.3527
# epoch =   98   loss = 0.5404
# epoch =   98   loss = 0.7585
# epoch =   98   loss = 0.9213
# epoch =   98   loss = 1.2438
# epoch =   99   loss = 0.3130
# epoch =   99   loss = 0.6569
# epoch =   99   loss = 0.8511
# epoch =   99   loss = 1.0341
# epoch =   99   loss = 1.1950
# Done

# %%
# train on the test set and return accuracy
def accuracy(model, ds):
  # ds is a PyTorch Dataset
  # assumes model = model.eval()
  n_correct = 0; n_wrong = 0

  for i in range(len(ds)):
    inpts = ds[i]['predictors'] 
    target = ds[i]['target']
    with torch.no_grad():
      oupt = model(inpts)

    print("----------")
    print("input:    " + str(inpts))
    print("target:   " + str(target))
    print("computed: " + str(oupt))

    # avoid 'target == 1.0'
    if target < 0.5 and oupt < 0.5:
      n_correct += 1
      print("correct")
    elif target >= 0.5 and oupt >= 0.5:
      n_correct += 1
      print("correct")
    else:
      n_wrong += 1
      print("wrong")

    print("----------")
  return (n_correct * 1.0) / (n_correct + n_wrong)

print("\nBegin accuracy() test ")

model = model.eval()
acc = accuracy(model, test_dataset)
print("\nAccuracy = %0.4f" % acc)

print("\nEnd test ")
# Out:
# Begin accuracy() test
# ----------
# input:    tensor([-0.2482, -0.2317, -0.6988, -0.7444, -0.5643, -0.6488, -0.8372, -0.7479,
#         -0.4829, -0.5579, -0.7219, -0.7797, -0.5980, -0.5091])
# target:   tensor([0.])
# computed: tensor([0.2035])
# correct
# ----------
# ----------
# input:    tensor([ 0.2071, -0.3388, -0.5344, -0.6257, -0.3667, -0.5465, -0.4988, -0.2853,
#         -0.5953, -0.5711, -0.6644, -0.7111, -0.5230, -0.6154])
# target:   tensor([0.])
# computed: tensor([0.2009])
# correct
# ----------
# ----------
# input:    tensor([ 0.4798, -0.7282,  0.5164,  0.9416, -0.0899, -0.2312,  0.1747,  1.2661,
#         -0.1115,  0.5492, -0.3587, -0.2247, -0.1423,  0.7271])
# target:   tensor([0.])
# computed: tensor([0.0363])
# correct
# ----------
# ----------
# input:    tensor([ 0.2990,  0.2732, -0.1097, -0.2574,  0.6383,  0.6614,  0.6178,  0.2592,
#         -0.0034,  0.0620,  0.4048,  0.2630,  0.1431, -0.0209])
# target:   tensor([0.])
# computed: tensor([0.0033])
# correct
# ----------
# ----------
# input:    tensor([ 1.3381,  0.8035,  0.8082,  0.1656,  1.3111,  0.7882,  1.9438,  0.5615,
#          0.5567,  0.3530, -0.1040, -0.4051,  0.0621, -0.1213])
# target:   tensor([0.])
# computed: tensor([0.0048])
# correct
# ----------
# ----------
# input:    tensor([-0.7493, -0.5365, -0.7442, -0.6360, -0.4533, -0.2577, -0.6731, -0.5492,
#         -0.6036, -0.5717, -0.7298, -0.7058, -0.7047, -0.5442])
# target:   tensor([0.])
# computed: tensor([0.1639])
# correct
# ----------
# ----------
# input:    tensor([-0.5964,  0.0896,  0.1961,  0.4481, -0.4427, -0.2572,  0.3139,  0.4779,
#          0.1560,  0.1616, -0.0914, -0.2583,  0.7429,  0.7991])
# target:   tensor([0.])
# computed: tensor([0.0133])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.9894, -0.8729, -1.1688, -0.9721, -0.8883, -0.7345,
#         -0.8390, -0.7811, -0.9099, -0.8307, -0.9524, -0.7708])
# target:   tensor([0.])
# computed: tensor([0.1228])
# correct
# ----------
# ----------
# input:    tensor([ 1.4928,  1.2393,  3.0986,  3.1787,  3.6842,  3.6688,  3.8953,  2.0780,
#         -0.2441, -0.4188,  1.1128,  2.0565,  0.5196,  0.9542])
# target:   tensor([0.])
# computed: tensor([0.0158])
# correct
# ----------
# ----------
# input:    tensor([-0.8852, -0.4432, -0.6300, -0.2697, -0.7181, -0.7012, -0.7880, -0.5468,
#         -0.6576, -0.5991, -0.4486, -0.5268, -0.4849, -0.4476])
# target:   tensor([0.])
# computed: tensor([0.3473])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8151, -0.8276, -0.3972, -0.4387, -1.1284, -0.8043,
#         -0.8490, -0.7764, -0.9526, -0.7400, -0.9971, -0.7576])
# target:   tensor([0.])
# computed: tensor([0.1407])
# correct
# ----------
# ----------
# input:    tensor([ 1.8023, -0.3388,  0.3740, -0.0952, -0.0407, -0.3136,  0.9260,  0.3264,
#         -0.3406, -0.1650, -0.6769, -0.6527, -0.4202, -0.5247])
# target:   tensor([0.])
# computed: tensor([0.0123])
# correct
# ----------
# ----------
# input:    tensor([ 0.4095,  1.3746,  0.5515,  0.3193, -0.3277, -0.5140,  0.2017, -0.2235,
#          0.8701,  0.3451,  0.1212, -0.3545,  0.5775, -0.1905])
# target:   tensor([0.])
# computed: tensor([0.0196])
# correct
# ----------
# ----------
# input:    tensor([0.8738, 0.8035, 0.9178, 0.4412, 1.5170, 1.2266, 0.1627, 0.3087, 1.9890,
#         1.2391, 3.4374, 2.8480, 1.1863, 0.7718])
# target:   tensor([0.])
# computed: tensor([0.0103])
# correct
# ----------
# ----------
# input:    tensor([-0.2799, -0.2609, -0.5932, -0.4915, -0.2212,  0.4703, -0.7057, -0.4946,
#         -0.6036, -0.5725,  0.1763,  0.4767, -0.5230, -0.2881])
# target:   tensor([0.])
# computed: tensor([0.1370])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8675, -0.8409, -0.9023, -0.8332, -1.2218, -0.8875,
#         -0.8771, -0.7876, -0.7914, -0.7954, -0.9614, -0.7678])
# target:   tensor([0.])
# computed: tensor([0.1696])
# correct
# ----------
# ----------
# input:    tensor([-0.0266, -0.0272,  0.3612,  0.7005,  0.4742,  0.2032,  0.2786,  0.1418,
#         -0.3854, -0.3436, -0.4564, -0.5992, -0.2934, -0.3461])
# target:   tensor([0.])
# computed: tensor([0.0383])
# correct
# ----------
# ----------
# input:    tensor([ 0.2071,  0.0896, -0.2436, -0.3786, -0.2936, -0.2713,  0.9316,  1.1102,
#         -0.2298, -0.3971,  0.5393,  0.5618,  1.1986,  1.0261])
# target:   tensor([0.])
# computed: tensor([0.0016])
# correct
# ----------
# ----------
# input:    tensor([ 0.1000, -1.1954,  0.4603, -0.1284, -0.2524, -0.6453,  0.2940, -0.2774,
#         -0.5081, -0.4088, -0.7996, -0.7509, -0.8587, -0.6410])
# target:   tensor([1.])
# computed: tensor([0.1870])
# wrong
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -1.0058, -0.8590, -1.0906, -0.9732, -1.1785, -0.8222,
#         -0.8753, -0.7798, -0.9283, -0.8210, -1.0470, -0.7732])
# target:   tensor([0.])
# computed: tensor([0.1410])
# correct
# ----------
# ----------
# input:    tensor([ 1.4928,  0.2064, -0.0144, -0.3447, -0.0948, -0.3756, -0.4762, -0.3873,
#         -0.3651, -0.4253, -0.1021, -0.1858,  0.1559,  0.3425])
# target:   tensor([0.])
# computed: tensor([0.0922])
# correct
# ----------
# ----------
# input:    tensor([ 0.4737,  1.1769,  0.8836,  0.8842,  0.8299,  1.3087,  1.0070,  1.2870,
#          0.0872, -0.0886,  0.2764,  0.4441,  0.8312,  0.6254])
# target:   tensor([0.])
# computed: tensor([0.0031])
# correct
# ----------
# ----------
# input:    tensor([ 1.0172, -0.9318, -0.0151, -0.1943,  0.2688,  0.1720, -0.0145, -0.2299,
#         -0.7527, -0.6653, -0.7678, -0.6554, -0.8659, -0.6300])
# target:   tensor([1.])
# computed: tensor([0.1338])
# wrong
# ----------
# ----------
# input:    tensor([ 0.3785,  1.7804, -0.3969, -0.3909, -0.1640,  0.2335, -0.0410, -0.0233,
#          2.7856,  3.2278,  3.3387,  3.6924,  2.0490,  1.8049])
# target:   tensor([0.])
# computed: tensor([0.0192])
# correct
# ----------
# ----------
# input:    tensor([1.9571, 1.8029, 1.5139, 0.5499, 1.8699, 0.7456, 0.9203, 0.2179, 0.7530,
#         0.2620, 1.5984, 0.7219, 0.8301, 0.4395])
# target:   tensor([0.])
# computed: tensor([0.0159])
# correct
# ----------
# ----------
# input:    tensor([-0.9446,  0.4108, -0.3873, -0.3632, -0.7826, -0.8248, -0.6764, -0.2284,
#         -0.0643,  0.1015, -0.2946, -0.0451, -0.0565,  0.1422])
# target:   tensor([0.])
# computed: tensor([0.2757])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8158, -0.8110, -1.0413, -0.9259, -0.9175, -0.7767,
#         -0.6590, -0.6901, -0.7704, -0.7257, -0.7440, -0.6699])
# target:   tensor([1.])
# computed: tensor([0.1411])
# wrong
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8286, -0.8229, -0.6754, -0.7591, -0.9266, -0.8011,
#         -0.7509, -0.7224, -0.4893, -0.5854, -0.7670, -0.6546])
# target:   tensor([0.])
# computed: tensor([0.1642])
# correct
# ----------
# ----------
# input:    tensor([-0.0548, -0.9099,  0.1392,  0.1645,  0.5119,  0.6341,  0.6929,  0.2395,
#         -0.7243, -0.7077, -0.6610, -0.7337, -0.7119, -0.5614])
# target:   tensor([0.])
# computed: tensor([0.0313])
# correct
# ----------
# ----------
# input:    tensor([-0.4970, -0.8283,  0.1966,  0.8532,  0.0793,  0.2667, -0.8631, -0.5125,
#         -0.6778, -0.6962, -0.5481, -0.5971, -0.3570, -0.5402])
# target:   tensor([1.])
# computed: tensor([0.7726])
# correct
# ----------
# ----------
# input:    tensor([-1.1007, -0.9201, -0.6888, -0.2291, -1.0525, -0.7599, -1.2523, -0.7128,
#         -0.2122,  0.7183, -0.4422,  0.0304, -0.5381,  0.2685])
# target:   tensor([1.])
# computed: tensor([0.5709])
# correct
# ----------
# ----------
# input:    tensor([-0.8852, -1.1954, -0.7871, -0.6727, -0.9461, -0.8720, -0.9292, -0.6732,
#         -0.7986, -0.7617, -0.8101, -0.7829, -0.8094, -0.7275])
# target:   tensor([0.])
# computed: tensor([0.1983])
# correct
# ----------
# ----------
# input:    tensor([-0.7493, -0.6683, -0.6703, -0.5355, -0.4085, -0.3411, -0.6355, -0.5295,
#         -0.5648, -0.5672, -0.7493, -0.7584, -0.5759, -0.5094])
# target:   tensor([1.])
# computed: tensor([0.2034])
# wrong
# ----------
# ----------
# input:    tensor([-0.7864, -0.8528, -0.1166,  0.5349, -0.5613, -0.0577, -0.6367, -0.0524,
#         -0.6397, -0.3773, -0.3425, -0.4352, -0.6314, -0.2728])
# target:   tensor([0.])
# computed: tensor([0.6223])
# wrong
# ----------
# ----------
# input:    tensor([ 1.4928,  1.3746,  8.9518,  3.7875,  6.6666,  3.6543, -0.6823, -0.8788,
#         -0.3765, -0.5304, -0.8602, -0.8174,  0.0464, -0.4244])
# target:   tensor([0.])
# computed: tensor([0.0129])
# correct
# ----------
# ----------
# input:    tensor([ 0.4798, -0.0272,  0.3931,  0.4468,  0.1833, -0.3037,  0.2067,  0.0324,
#         -0.3592, -0.4319, -0.4427, -0.4015, -0.3588, -0.3747])
# target:   tensor([0.])
# computed: tensor([0.0383])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8228, -0.8092, -0.4220, -0.2519, -0.3607, -0.2019,
#         -0.8278, -0.8014, -0.9460, -0.8912, -1.1012, -0.8385])
# target:   tensor([0.])
# computed: tensor([0.1409])
# correct
# ----------
# ----------
# input:    tensor([-0.7493, -0.2729, -0.6620, -0.4658, -0.4370, -0.2564, -0.7388, -0.6635,
#         -0.5210, -0.5256, -0.5481, -0.4778, -0.5351, -0.3781])
# target:   tensor([1.])
# computed: tensor([0.1870])
# wrong
# ----------
# ----------
# input:    tensor([-0.0548, -0.0532, -0.4213, -0.6120, -0.1760, -0.2939, -0.0867, -0.2050,
#         -0.4306, -0.4392, -0.2021, -0.1434, -0.4942, -0.4095])
# target:   tensor([0.])
# computed: tensor([0.0521])
# correct
# ----------
# ----------
# input:    tensor([-0.7357, -0.9249, -0.6782, -0.4665, -0.5635, -0.3115, -0.8646, -0.5660,
#         -0.8531, -0.7362, -0.8524, -0.6610, -0.8691, -0.6681])
# target:   tensor([0.])
# computed: tensor([0.2001])
# correct
# ----------
# ----------
# input:    tensor([1.1833, 0.2324, 0.4095, 0.0558, 0.7873, 0.3671, 1.5725, 0.6202, 0.1123,
#         0.0720, 0.1174, 0.0588, 0.3840, 0.0752])
# target:   tensor([0.])
# computed: tensor([0.0030])
# correct
# ----------
# ----------
# input:    tensor([-0.8852,  0.9133, -0.7464, -0.6571, -0.6514, -0.8097, -0.6532, -0.5272,
#         -0.0945, -0.2795,  0.7387,  0.4902,  0.6513,  0.3736])
# target:   tensor([0.])
# computed: tensor([0.4289])
# correct
# ----------
# ----------
# input:    tensor([0.1000, 2.6596, 2.2306, 1.6113, 0.7616, 0.8243, 2.3605, 0.7721, 2.8374,
#         1.8003, 0.3553, 0.2982, 2.2448, 0.8041])
# target:   tensor([0.])
# computed: tensor([0.0087])
# correct
# ----------
# ----------
# input:    tensor([ 0.0660, -0.2729, -0.3380, -0.3721, -0.2711, -0.3924, -0.1415, -0.0577,
#         -0.6147, -0.6491, -0.3772, -0.4407, -0.0657,  0.1042])
# target:   tensor([0.])
# computed: tensor([0.0666])
# correct
# ----------
# ----------
# input:    tensor([-0.3417, -0.4047, -0.5237, -0.4033, -0.5285, -0.5970, -0.3998, -0.4029,
#         -0.5342, -0.5336, -0.3154, -0.3362, -0.5484, -0.3323])
# target:   tensor([0.])
# computed: tensor([0.1574])
# correct
# ----------
# ----------
# input:    tensor([ 0.2990,  0.8606,  0.4505,  0.3048,  0.0165, -0.1343,  0.0526, -0.2222,
#          0.2746,  0.0557,  0.0511, -0.1444,  0.1719, -0.1182])
# target:   tensor([0.])
# computed: tensor([0.0178])
# correct
# ----------
# ----------
# input:    tensor([ 9.9981e-02,  6.6070e-01, -1.1139e-01, -3.8847e-02, -2.8407e-01,
#         -2.3652e-01,  2.9636e-01, -1.5173e-01,  1.6314e-01, -5.9253e-04,
#         -1.4074e-01, -3.8159e-01,  1.1885e+00,  9.1617e-01])
# target:   tensor([0.])
# computed: tensor([0.0094])
# correct
# ----------
# ----------
# input:    tensor([-0.0072, -0.3388,  0.5628,  1.8037,  0.6772,  0.7048,  1.1893,  0.7828,
#          0.0925,  0.8427, -0.3094,  0.2658,  0.0530,  0.1797])
# target:   tensor([0.])
# computed: tensor([0.0154])
# correct
# ----------
# ----------
# input:    tensor([ 0.2990, -0.4611, -0.2581, -0.4262, -0.8191, -0.8523, -0.9052, -0.8179,
#         -0.4059, -0.4168, -0.6283, -0.7823, -0.9038, -0.7005])
# target:   tensor([0.])
# computed: tensor([0.4662])
# correct
# ----------
# ----------
# input:    tensor([-0.8643, -0.4047, -0.6814, -0.8033, -0.3733, -0.6041, -0.7150, -0.6508,
#         -0.6330, -0.6157, -0.7882, -0.6558, -0.7229, -0.5778])
# target:   tensor([0.])
# computed: tensor([0.1323])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8084, -0.8357, -0.8672, -0.9159, -0.9672, -0.8318,
#         -0.7880, -0.7467, -0.7892, -0.7440, -0.9452, -0.7427])
# target:   tensor([0.])
# computed: tensor([0.1454])
# correct
# ----------
# ----------
# input:    tensor([-0.0266, -0.9618, -0.3247, -0.3172,  0.8742,  1.5827, -0.2514, -0.3559,
#         -0.7890, -0.7129, -0.5652, -0.4260, -1.0537, -0.7688])
# target:   tensor([0.])
# computed: tensor([0.1038])
# correct
# ----------
# ----------
# input:    tensor([-0.1786, -1.1954, -0.5677, -0.6007,  0.3166,  0.6409, -0.9676, -0.7870,
#         -0.8176, -0.7609, -0.8697, -0.8402, -0.8886, -0.7622])
# target:   tensor([0.])
# computed: tensor([0.3247])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8833, -0.8044, -0.7867, -0.8148, -1.0770, -0.7700,
#         -0.8258, -0.7654, -0.9285, -0.8162, -0.9793, -0.7957])
# target:   tensor([0.])
# computed: tensor([0.1614])
# correct
# ----------
# ----------
# input:    tensor([ 1.8023,  0.8035,  1.6817,  1.0111,  1.0034,  0.1335,  1.5408,  0.1130,
#          0.6986,  0.3620, -0.1068, -0.3771,  0.4216,  0.0098])
# target:   tensor([0.])
# computed: tensor([0.0100])
# correct
# ----------
# ----------
# input:    tensor([ 0.4798, -0.2609,  1.2299,  2.0711,  1.3942,  2.0318,  2.4702,  2.8692,
#         -0.4624, -0.5048, -0.4761, -0.5927, -0.7188, -0.6701])
# target:   tensor([0.])
# computed: tensor([0.0091])
# correct
# ----------
# ----------
# input:    tensor([-0.7864, -0.7282, -0.5795, -0.5816, -0.4487, -0.1423, -0.6829, -0.4085,
#         -0.6434, -0.4151, -0.3028,  0.5056, -0.1854,  0.5048])
# target:   tensor([0.])
# computed: tensor([0.0556])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.7804, -0.8402, -0.6429, -0.7256, -0.5100, -0.7376,
#         -0.7973, -0.7825, -0.7008, -0.7904, -0.8537, -0.6529])
# target:   tensor([0.])
# computed: tensor([0.1244])
# correct
# ----------
# ----------
# input:    tensor([ 0.0660, -0.6683, -0.1510, -0.0719, -0.2505, -0.2159, -0.4591, -0.3437,
#         -0.6755, -0.6475, -0.5248, -0.5882, -0.4155, -0.3004])
# target:   tensor([0.])
# computed: tensor([0.2784])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -0.9447, -0.8871, -0.8436, -0.9196, -0.8857, -1.0134, -0.8277,
#         -0.7103, -0.4272, -0.7944, -0.7526, -0.8189, -0.6153])
# target:   tensor([0.])
# computed: tensor([0.2179])
# correct
# ----------
# ----------
# input:    tensor([ 4.2141e-01, -1.1954e+00,  4.1735e-04,  3.8208e-01, -7.8389e-01,
#         -7.1811e-01, -4.6551e-01, -6.3359e-01, -7.8729e-01, -7.2922e-01,
#         -8.5732e-01, -7.5331e-01, -8.2815e-01, -7.3399e-01])
# target:   tensor([0.])
# computed: tensor([0.5784])
# wrong
# ----------
# ----------
# input:    tensor([ 1.2143,  0.6983,  1.7050,  0.9275,  6.3677,  5.4386,  0.1469, -0.0323,
#          0.4407,  0.4474,  0.1504,  0.5321,  0.8483,  0.4840])
# target:   tensor([0.])
# computed: tensor([0.0314])
# correct
# ----------
# ----------
# input:    tensor([-0.8643,  0.0896, -0.1861,  0.4611, -0.6988, -0.6980, -0.8082, -0.5862,
#         -0.0733,  0.2162, -0.3389, -0.5668, -0.6478, -0.6178])
# target:   tensor([1.])
# computed: tensor([0.8971])
# correct
# ----------
# ----------
# input:    tensor([ 0.2266, -0.7282, -0.0993, -0.0215,  0.5663,  0.9972, -0.3605, -0.1447,
#         -0.7348, -0.6718, -0.5428, -0.4971, -0.6994, -0.5349])
# target:   tensor([0.])
# computed: tensor([0.1536])
# correct
# ----------
# ----------
# input:    tensor([-0.2214,  1.8029,  0.1309,  0.5541,  0.0338,  0.2984,  0.1606,  0.3436,
#          0.7455,  0.6468,  0.2211,  0.3180,  0.8275,  0.3193])
# target:   tensor([0.])
# computed: tensor([0.0098])
# correct
# ----------
# ----------
# input:    tensor([-0.7493, -0.1411, -0.6569, -0.5158, -0.6767, -0.5921, -1.0360, -0.7306,
#         -0.3253, -0.2923, -0.5004, -0.5705, -0.3669, -0.2867])
# target:   tensor([1.])
# computed: tensor([0.3929])
# wrong
# ----------
# ----------
# input:    tensor([ 0.2990,  0.2732, -0.5753, -0.7136, -0.1010, -0.5745, -0.2010,  0.0436,
#          1.8308,  3.0307,  1.1550,  1.4817,  0.7110,  1.2654])
# target:   tensor([0.])
# computed: tensor([0.0447])
# correct
# ----------
# ----------
# input:    tensor([ 0.2990,  1.0075, -0.0731, -0.3345, -0.9726, -0.8630, -0.9110, -0.7449,
#          0.0445, -0.2696, -0.3897, -0.1362, -0.2042,  0.0083])
# target:   tensor([1.])
# computed: tensor([0.1544])
# wrong
# ----------
# ----------
# input:    tensor([-0.8286, -0.7671, -0.8146, -0.6640, -0.6354, -0.2387, -0.4126,  0.1661,
#         -0.8269, -0.7238, -0.7103, -0.6890, -0.7910, -0.6144])
# target:   tensor([1.])
# computed: tensor([0.1402])
# wrong
# ----------
# ----------
# input:    tensor([-0.3417, -0.5365, -0.5488, -0.5932, -0.4525, -0.5367, -0.3475, -0.2912,
#         -0.5751, -0.5040, -0.5382, -0.5870, -0.5319, -0.5611])
# target:   tensor([0.])
# computed: tensor([0.1736])
# correct
# ----------
# ----------
# input:    tensor([-1.0786, -0.5529, -0.7462, -0.5316, -0.7131, -0.4571, -0.8301, -0.5142,
#         -0.5519, -0.5742, -0.5052, -0.5436, -0.6540, -0.6560])
# target:   tensor([1.])
# computed: tensor([0.2437])
# wrong
# ----------
# ----------
# input:    tensor([ 3.3499,  1.5174,  2.2123,  0.4797,  0.2761, -0.3876,  0.7626, -0.2346,
#         -0.0667, -0.4490, -0.0448, -0.0090,  0.6949,  0.1062])
# target:   tensor([0.])
# computed: tensor([0.0145])
# correct
# ----------
# ----------
# input:    tensor([0.8738, 1.0890, 2.4391, 2.3642, 3.7356, 3.5329, 3.0257, 1.3945, 0.6252,
#         0.6184, 0.3754, 0.4678, 0.6384, 0.5851])
# target:   tensor([0.])
# computed: tensor([0.0128])
# correct
# ----------
# ----------
# input:    tensor([-1.2929, -1.1954, -0.8770, -0.8343, -0.6476, -0.6524, -0.8210, -0.7621,
#         -0.8008, -0.7601, -0.5056, -0.6260, -0.9854, -0.7108])
# target:   tensor([0.])
# computed: tensor([0.1493])
# correct
# ----------
# ----------
# input:    tensor([ 1.3381,  2.0885,  1.0827,  0.5797,  0.7098,  0.0262,  0.9210,  0.0819,
#          1.5076,  0.5373,  0.7139, -0.0866,  0.8056,  0.0623])
# target:   tensor([0.])
# computed: tensor([0.0161])
# correct
# ----------
# ----------
# input:    tensor([ 0.9357,  0.1572,  0.5389,  0.4613,  0.0572,  0.1882,  1.8196,  2.3665,
#          0.1473,  0.2180, -0.1883,  0.3658,  1.2870,  2.0409])
# target:   tensor([0.])
# computed: tensor([0.0014])
# correct
# ----------
# ----------
# input:    tensor([-0.8852,  0.7815, -0.6790, -0.6405, -0.4656, -0.4067, -0.4534, -0.2030,
#         -0.0307, -0.1394,  0.9512,  0.9330,  0.2251, -0.0338])
# target:   tensor([0.])
# computed: tensor([0.1725])
# correct
# ----------
# ----------
# input:    tensor([ 0.4737, -0.0093, -0.2322, -0.3248,  0.0411, -0.2831, -0.0546, -0.2161,
#         -0.4701, -0.5296, -0.1552, -0.3433, -0.0713,  0.0021])
# target:   tensor([0.])
# computed: tensor([0.0626])
# correct
# ----------
#
# Accuracy = 0.8590
#
# End test
