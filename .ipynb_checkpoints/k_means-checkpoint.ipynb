# %%
import requests
import math
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
import pandas as pd
from sklearn import linear_model
from scipy import stats as st
from PIL import Image
from scipy.stats import norm
import scipy.stats as stat
from scipy.stats import beta
from scipy.stats import triang
from scipy.stats import lognorm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
import statsmodels.formula.api as smf
import statsmodels.api as sm
import sklearn.linear_model as lm

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay

# %%
import json
import glob
import os
from pathlib import Path

from epilepsypcm.utils.make_df import make_df, get_df_list, concat_dfs
from epilepsypcm.utils.outcome_params import seizure_onset_zone, engel_score
from epilepsypcm.loading.imports import respInfoToAdjacencyMatrix, zToAdjacencyMatrix, getPeakLatency

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import warnings
warnings.filterwarnings('ignore')

#Location
base_path = '/Users/cindy/Desktop/ToCindy/JHU/FA21/PCM1/data/' #modify for your file location



#Function to get a list of all dataframes for all positive patients, in the format [patient number, df]
df_list = get_df_list(base_path, "1")

#Code to loop through this list
#for i in range(len(df_list)):
#    print("Patient ID: ", df_list[i][0])
#    print("Patient Dataframe: ", df_list[i][1].head(3))

    
#Function to get the concatenated dataframe for all positive patients
all_positive_patients = concat_dfs(base_path, "1")
print("Full Dataframe: ", all_positive_patients.head(3))
# Out:
# Full Dataframe:     chNames  significant  n1Zscore  n2Zscore  p2Zscore  n1Latency  n2Latency  \
# 2  LA3_LA4          0.0  1.396644  1.062212 -5.025081       13.0      180.0
# 6  LA7_LA8          0.0  1.371992  1.735958 -0.305671       17.0      131.0
# 7  LA8_LA9          0.0  1.990935  0.596185  0.596185       19.0      101.0
#
#    p2Latency  flipped  outcome
# 2       43.0      1.0      1.0
# 6       47.0      1.0      0.0
# 7      101.0      1.0      0.0

# %%
all_positive_patients
# Out:
#          chNames  significant  n1Zscore  n2Zscore  p2Zscore  n1Latency  \
# 2        LA3_LA4          0.0  1.396644  1.062212 -5.025081       13.0
# 6        LA7_LA8          0.0  1.371992  1.735958 -0.305671       17.0
# 7        LA8_LA9          0.0  1.990935  0.596185  0.596185       19.0
# 10     LAH2_LAH3          0.0  4.324042  4.524443 -1.176967       16.0
# 11     LAH3_LAH4          0.0  4.214433  2.351241 -1.154445       15.0
# ..           ...          ...       ...       ...       ...        ...
# 706  RPFS6_RPFS7          0.0 -0.775927 -2.579947  4.290270       51.0
# 707  RPFS7_RPFS8          0.0  1.769931  5.228859 -3.093837       12.0
# 708  RPFI1_RPFI2          0.0  1.361718  2.097774 -1.999799       14.0
# 709  RPFI2_RPFI3          0.0 -2.863802 -2.631576  7.996893       44.0
# 710  RPFI3_RPFI4          0.0  4.730472  6.498267 -4.460485       16.0
#
#      n2Latency  p2Latency  flipped  outcome
# 2        180.0       43.0      1.0      1.0
# ...

# %%
keys = all_positive_patients.keys()[2:8]
X = all_positive_patients[keys]
y = all_positive_patients.outcome
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X
# Out:
#      n1Zscore  n2Zscore  p2Zscore  n1Latency  n2Latency  p2Latency
# 2    1.396644  1.062212 -5.025081       13.0      180.0       43.0
# 6    1.371992  1.735958 -0.305671       17.0      131.0       47.0
# 7    1.990935  0.596185  0.596185       19.0      101.0      101.0
# 10   4.324042  4.524443 -1.176967       16.0      101.0       45.0
# 11   4.214433  2.351241 -1.154445       15.0      110.0       43.0
# ..        ...       ...       ...        ...        ...        ...
# 706 -0.775927 -2.579947  4.290270       51.0      285.0      195.0
# 707  1.769931  5.228859 -3.093837       12.0      139.0       69.0
# 708  1.361718  2.097774 -1.999799       14.0      338.0      278.0
# 709 -2.863802 -2.631576  7.996893       44.0      228.0      118.0
# 710  4.730472  6.498267 -4.460485       16.0      143.0       79.0
#
# [19524 rows x 6 columns]

# %%
sse = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, n_init=100)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
    
plt.plot(range(1, 11), sse)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.grid()
plt.show()
    
from kneed import KneeLocator
kl = KneeLocator( range(1, 11), sse, curve="convex", direction="decreasing")
print('Number of Clusters: ', kl.elbow)
# Out:
# Number of Clusters:  3

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = [] 
    
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, n_init=100)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(score)

# Lineplot using silhouette score
plt.plot(range(2, 11), silhouette_scores) 
plt.xlabel('K - Number of Clusters') 
plt.ylabel('Silhouette score') 
plt.title('The Silhouette Method') 
plt.show()

# %% [markdown]
# # If 2 clusters

# %%
kmeans1 = KMeans(n_clusters=2, n_init=100)
clusters1 = kmeans1.fit_predict(all_positive_patients[['n1Zscore', 'n2Zscore', 'p2Zscore', 'n1Latency','n2Latency','p2Latency']])
all_positive_patients['cluster2'] = clusters1
all_positive_patients
# Out:
#          chNames  significant  n1Zscore  n2Zscore  p2Zscore  n1Latency  \
# 2        LA3_LA4          0.0  1.396644  1.062212 -5.025081       13.0
# 6        LA7_LA8          0.0  1.371992  1.735958 -0.305671       17.0
# 7        LA8_LA9          0.0  1.990935  0.596185  0.596185       19.0
# 10     LAH2_LAH3          0.0  4.324042  4.524443 -1.176967       16.0
# 11     LAH3_LAH4          0.0  4.214433  2.351241 -1.154445       15.0
# ..           ...          ...       ...       ...       ...        ...
# 706  RPFS6_RPFS7          0.0 -0.775927 -2.579947  4.290270       51.0
# 707  RPFS7_RPFS8          0.0  1.769931  5.228859 -3.093837       12.0
# 708  RPFI1_RPFI2          0.0  1.361718  2.097774 -1.999799       14.0
# 709  RPFI2_RPFI3          0.0 -2.863802 -2.631576  7.996893       44.0
# 710  RPFI3_RPFI4          0.0  4.730472  6.498267 -4.460485       16.0
#
#      n2Latency  p2Latency  flipped  outcome  cluster2
# 2        180.0       43.0      1.0      1.0         0
# ...

# %%
df1 = all_positive_patients.iloc[:,2:11].drop(columns=['flipped','outcome'])
df1
# Out:
#      n1Zscore  n2Zscore  p2Zscore  n1Latency  n2Latency  p2Latency  cluster2
# 2    1.396644  1.062212 -5.025081       13.0      180.0       43.0         0
# 6    1.371992  1.735958 -0.305671       17.0      131.0       47.0         0
# 7    1.990935  0.596185  0.596185       19.0      101.0      101.0         0
# 10   4.324042  4.524443 -1.176967       16.0      101.0       45.0         0
# 11   4.214433  2.351241 -1.154445       15.0      110.0       43.0         0
# ..        ...       ...       ...        ...        ...        ...       ...
# 706 -0.775927 -2.579947  4.290270       51.0      285.0      195.0         0
# 707  1.769931  5.228859 -3.093837       12.0      139.0       69.0         0
# 708  1.361718  2.097774 -1.999799       14.0      338.0      278.0         1
# 709 -2.863802 -2.631576  7.996893       44.0      228.0      118.0         0
# 710  4.730472  6.498267 -4.460485       16.0      143.0       79.0         0
#
# [19524 rows x 7 columns]

# %%
pd.plotting.parallel_coordinates(df1,'cluster2')
plt.title('parallel coordinates of cluster labels')
# Out:
# Text(0.5, 1.0, 'parallel coordinates of cluster labels')

# %%
plt.scatter(X.iloc[:,3], X.iloc[:,4], c=kmeans1.labels_, cmap=cm.rainbow)
plt.title('n1Latency VS n2Latency clustering')
plt.xlabel('n1Latency')
plt.ylabel('n2Latency')
C = kmeans1.cluster_centers_
scatter(C[:,3], C[:,4], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %%
plt.scatter(X.iloc[:,4], X.iloc[:,5], c=kmeans1.labels_, cmap=cm.rainbow)
plt.title('n2Latency VS p2Latency clustering')
plt.xlabel('n2Latency')
plt.ylabel('p2Latency')
C = kmeans1.cluster_centers_
scatter(C[:,4], C[:,5], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %%
plt.scatter(X.iloc[:,3], X.iloc[:,5], c=kmeans1.labels_, cmap=cm.rainbow)
plt.title('n1Latency VS p2Latency clustering')
plt.xlabel('n1Latency')
plt.ylabel('p2Latency')
C = kmeans1.cluster_centers_
scatter(C[:,3], C[:,5], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %% [markdown]
# # If 3 clusters

# %%
kmeans2 = KMeans(n_clusters=3, n_init=100)
clusters2 = kmeans2.fit_predict(all_positive_patients[['n1Zscore', 'n2Zscore', 'p2Zscore', 'n1Latency','n2Latency','p2Latency']])
all_positive_patients['cluster3'] = clusters2
all_positive_patients
# Out:
#          chNames  significant  n1Zscore  n2Zscore  p2Zscore  n1Latency  \
# 2        LA3_LA4          0.0  1.396644  1.062212 -5.025081       13.0
# 6        LA7_LA8          0.0  1.371992  1.735958 -0.305671       17.0
# 7        LA8_LA9          0.0  1.990935  0.596185  0.596185       19.0
# 10     LAH2_LAH3          0.0  4.324042  4.524443 -1.176967       16.0
# 11     LAH3_LAH4          0.0  4.214433  2.351241 -1.154445       15.0
# ..           ...          ...       ...       ...       ...        ...
# 706  RPFS6_RPFS7          0.0 -0.775927 -2.579947  4.290270       51.0
# 707  RPFS7_RPFS8          0.0  1.769931  5.228859 -3.093837       12.0
# 708  RPFI1_RPFI2          0.0  1.361718  2.097774 -1.999799       14.0
# 709  RPFI2_RPFI3          0.0 -2.863802 -2.631576  7.996893       44.0
# 710  RPFI3_RPFI4          0.0  4.730472  6.498267 -4.460485       16.0
#
#      n2Latency  p2Latency  flipped  outcome  cluster2  cluster3
# ...

# %%
df2 = all_positive_patients.iloc[:,2:12].drop(columns=['flipped','outcome','cluster2'])
df2
# Out:
#      n1Zscore  n2Zscore  p2Zscore  n1Latency  n2Latency  p2Latency  cluster3
# 2    1.396644  1.062212 -5.025081       13.0      180.0       43.0         0
# 6    1.371992  1.735958 -0.305671       17.0      131.0       47.0         0
# 7    1.990935  0.596185  0.596185       19.0      101.0      101.0         0
# 10   4.324042  4.524443 -1.176967       16.0      101.0       45.0         0
# 11   4.214433  2.351241 -1.154445       15.0      110.0       43.0         0
# ..        ...       ...       ...        ...        ...        ...       ...
# 706 -0.775927 -2.579947  4.290270       51.0      285.0      195.0         1
# 707  1.769931  5.228859 -3.093837       12.0      139.0       69.0         0
# 708  1.361718  2.097774 -1.999799       14.0      338.0      278.0         1
# 709 -2.863802 -2.631576  7.996893       44.0      228.0      118.0         0
# 710  4.730472  6.498267 -4.460485       16.0      143.0       79.0         0
#
# [19524 rows x 7 columns]

# %%
pd.plotting.parallel_coordinates(df2,'cluster3')
plt.title('parallel coordinates of cluster labels')
# Out:
# Text(0.5, 1.0, 'parallel coordinates of cluster labels')

# %%
plt.scatter(X.iloc[:,3], X.iloc[:,4], c=kmeans2.labels_, cmap=cm.rainbow)
plt.title('n1Latency VS n2Latency clustering')
plt.xlabel('n1Latency')
plt.ylabel('n2Latency')
C = kmeans2.cluster_centers_
scatter(C[:,3], C[:,4], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %%
plt.scatter(X.iloc[:,4], X.iloc[:,5], c=kmeans2.labels_, cmap=cm.rainbow)
plt.title('n2Latency VS p2Latency clustering')
plt.xlabel('n2Latency')
plt.ylabel('p2Latency')
C = kmeans2.cluster_centers_
scatter(C[:,4], C[:,5], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %%
plt.scatter(X.iloc[:,3], X.iloc[:,5], c=kmeans2.labels_, cmap=cm.rainbow)
plt.title('n1Latency VS p2Latency clustering')
plt.xlabel('n1Latency')
plt.ylabel('p2Latency')
C = kmeans2.cluster_centers_
scatter(C[:,3], C[:,5], c='k', marker='o', s=300, alpha=0.5, edgecolor='none')

# %% [markdown]
# # Compare clusters with labels

# %%
all_positive_patients
# Out:
#          chNames  significant  n1Zscore  n2Zscore  p2Zscore  n1Latency  \
# 2        LA3_LA4          0.0  1.396644  1.062212 -5.025081       13.0
# 6        LA7_LA8          0.0  1.371992  1.735958 -0.305671       17.0
# 7        LA8_LA9          0.0  1.990935  0.596185  0.596185       19.0
# 10     LAH2_LAH3          0.0  4.324042  4.524443 -1.176967       16.0
# 11     LAH3_LAH4          0.0  4.214433  2.351241 -1.154445       15.0
# ..           ...          ...       ...       ...       ...        ...
# 706  RPFS6_RPFS7          0.0 -0.775927 -2.579947  4.290270       51.0
# 707  RPFS7_RPFS8          0.0  1.769931  5.228859 -3.093837       12.0
# 708  RPFI1_RPFI2          0.0  1.361718  2.097774 -1.999799       14.0
# 709  RPFI2_RPFI3          0.0 -2.863802 -2.631576  7.996893       44.0
# 710  RPFI3_RPFI4          0.0  4.730472  6.498267 -4.460485       16.0
#
#      n2Latency  p2Latency  flipped  outcome  cluster2  cluster3
# ...

# %%
print('Accuracy of 2 Clusters with outcome:', np.where(all_positive_patients.outcome == all_positive_patients.cluster2)[0].size/len(all_positive_patients.outcome))
print('Accuracy of 3 Clusters with outcome:', np.where(all_positive_patients.outcome == all_positive_patients.cluster3)[0].size/len(all_positive_patients.outcome))
# Out:
# Accuracy of 2 Clusters with outcome: 0.7933312845728334
# Accuracy of 3 Clusters with outcome: 0.5

# %% [markdown]
# ### Original Data analysis

# %%
print('percent of 0 in labels:', np.where(all_positive_patients.outcome == 0)[0].size/len(all_positive_patients.outcome))
print('percent of 1 in labels:', np.where(all_positive_patients.outcome == 1)[0].size/len(all_positive_patients.outcome))
# Out:
# percent of 0 in labels: 0.9149252202417537
# percent of 1 in labels: 0.08507477975824626

# %% [markdown]
# ### Would suggest using 2 clusters

# %%
# Within 2 clusters, #0 cluster

df1 = all_positive_patients[all_positive_patients.cluster2==0]
print('percent of 0 in cluster#0 of 2 clusters:', np.where(df1.outcome == 0)[0].size/len(df1.outcome))
print('percent of 1 in cluster#0 of 2 clusters:', np.where(df1.outcome == 1)[0].size/len(df1.outcome))

print('-----------------------------------------------------------------')
# Within 2 clusters, #1 cluster

df2 = all_positive_patients[all_positive_patients.cluster2==1]
print('percent of 0 in cluster#1 of 2 clusters:', np.where(df2.outcome == 0)[0].size/len(df2.outcome))
print('percent of 1 in cluster#1 of 2 clusters:', np.where(df2.outcome == 1)[0].size/len(df2.outcome))
# Out:
# percent of 0 in cluster#0 of 2 clusters: 0.9155547541771848
# percent of 1 in cluster#0 of 2 clusters: 0.08444524582281525
# -----------------------------------------------------------------
# percent of 0 in cluster#1 of 2 clusters: 0.9112959112959113
# percent of 1 in cluster#1 of 2 clusters: 0.0887040887040887

# %% [markdown]
# ### If using 3 clusters

# %%
# Within 3 clusters, #0 cluster

df3 = all_positive_patients[all_positive_patients.cluster3==0]
print('percent of 0 in cluster#0 of 3 clusters:', np.where(df3.outcome == 0)[0].size/len(df3.outcome))
print('percent of 1 in cluster#0 of 3 clusters:', np.where(df3.outcome == 1)[0].size/len(df3.outcome))

print('-----------------------------------------------------------------')

# Within 3 clusters, #1 cluster

df4 = all_positive_patients[all_positive_patients.cluster3==1]
print('percent of 0 in cluster#0 of 3 clusters:', np.where(df4.outcome == 0)[0].size/len(df4.outcome))
print('percent of 1 in cluster#0 of 3 clusters:', np.where(df4.outcome == 1)[0].size/len(df4.outcome))

print('-----------------------------------------------------------------')

# Within 3 clusters, #2 cluster

df5 = all_positive_patients[all_positive_patients.cluster3==2]
print('percent of 0 in cluster#0 of 3 clusters:', np.where(df5.outcome == 0)[0].size/len(df5.outcome))
print('percent of 1 in cluster#0 of 3 clusters:', np.where(df5.outcome == 1)[0].size/len(df5.outcome))
# Out:
# percent of 0 in cluster#0 of 3 clusters: 0.9160712488678676
# percent of 1 in cluster#0 of 3 clusters: 0.08392875113213244
# -----------------------------------------------------------------
# percent of 0 in cluster#0 of 3 clusters: 0.9126573889993373
# percent of 1 in cluster#0 of 3 clusters: 0.08734261100066269
# -----------------------------------------------------------------
# percent of 0 in cluster#0 of 3 clusters: 0.9177277179236043
# percent of 1 in cluster#0 of 3 clusters: 0.08227228207639568
